# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely import wkt
from matplotlib import pyplot
import descartes
import seaborn as sns
import datetime as dt
import geoplot as geoplot
from sklearn.preprocessing import MultiLabelBinarizer

# %%
#create pandas dataframe of datasets
listings = pd.read_csv('../data/raw/listings.csv')
market_value = pd.read_csv('../data/raw/Market_Value_Analysis__2018_data.csv', index_col = False)
restaurants = pd.read_csv('../data/raw/Culinary_Arts_data.csv', index_col = False)

# %%
print(listings.head())
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10291  https://www.airbnb.com/rooms/10291  20200909145511   2020-09-10
# 1  19091  https://www.airbnb.com/rooms/19091  20200909145511   2020-09-10
# 2  26834  https://www.airbnb.com/rooms/26834  20200909145511   2020-09-09
# 3  71624  https://www.airbnb.com/rooms/71624  20200909145511   2020-09-10
# 4  74498  https://www.airbnb.com/rooms/74498  20200909145511   2020-09-10
#
#                                   name  \
# 0        Spacious Cottage in Mid-City!
# 1       Fully Furnished Cozy Apartment
# 2     Maison Mandeville in the Marigny
# 3   Ravenwood Manor (Historic Bywater)
# 4  Maison Marais 1: Large Local Living
#
#                                          description  \
# 0  <b>The space</b><br />Spacious house located i...
# 1  CITY OF NEW ORLEANS STR LICENSE PERMIT NUMBER:...
# 2  <b>The space</b><br />Charming shotgun apartme...
# 3  You are in for a very unique stay in a neighbo...
# 4  Maison Marais 1 is a stylish one-bedroom apart...
#
#                                neighborhood_overview  \
# 0  Navarre is a quiet and quaint neighborhood tha...
# 1  NorthWest Carrollton, where this apartment is ...
# 2                                                NaN
# 3  Ours is a neighborhood made up of artists, mus...
# 4  This is a vibrant, diverse neighborhood of mos...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/99566384/fd1d...    31004
# 1  https://a0.muscache.com/pictures/a5fdfd3b-5d81...    72880
# 2  https://a0.muscache.com/pictures/505025/bee98a...   114452
# 3  https://a0.muscache.com/pictures/37488608/8cc1...   367223
# 4  https://a0.muscache.com/pictures/73591836/a1f5...   391462
#
#                                    host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/31004  ...                        10.0
# 1   https://www.airbnb.com/users/show/72880  ...                        10.0
# 2  https://www.airbnb.com/users/show/114452  ...                        10.0
# 3  https://www.airbnb.com/users/show/367223  ...                        10.0
# 4  https://www.airbnb.com/users/show/391462  ...                        10.0
#
#   review_scores_location review_scores_value  \
# 0                   10.0                10.0
# 1                   10.0                10.0
# 2                   10.0                10.0
# 3                   10.0                10.0
# 4                   10.0                10.0
#
#                                              license instant_bookable  \
# 0                          19STR-08424, 19-OSTR-0313                f
# 1                          17STR-08877, 20-OSTR-0105                t
# 2                          19STR-10811, 20-OSTR-0389                f
# 3                                        17STR-08285                f
# 4  Exempt: This listing is a licensed hotel, mote...                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              1                                           1
# 3                              1                                           1
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.08
# 1                                           0              3.69
# 2                                           0              2.06
# 3                                           0              1.94
# 4                                           0              4.29
#
# [5 rows x 74 columns]

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6408 non-null   int64
#  1   listing_url                                   6408 non-null   object
#  2   scrape_id                                     6408 non-null   int64
#  3   last_scraped                                  6408 non-null   object
#  4   name                                          6408 non-null   object
#  5   description                                   6383 non-null   object
#  6   neighborhood_overview                         4819 non-null   object
#  7   picture_url                                   6408 non-null   object
#  8   host_id                                       6408 non-null   int64
#  9   host_url                                      6408 non-null   object
#  10  host_name                                     6408 non-null   object
#  11  host_since                                    6408 non-null   object
#  12  host_location                                 6396 non-null   object
#  13  host_about                                    4226 non-null   object
#  14  host_response_time                            4801 non-null   object
#  15  host_response_rate                            4801 non-null   object
#  16  host_acceptance_rate                          5877 non-null   object
#  17  host_is_superhost                             6408 non-null   object
#  18  host_thumbnail_url                            6408 non-null   object
#  19  host_picture_url                              6408 non-null   object
#  20  host_neighbourhood                            5665 non-null   object
#  21  host_listings_count                           6408 non-null   int64
#  22  host_total_listings_count                     6408 non-null   int64
#  23  host_verifications                            6408 non-null   object
#  24  host_has_profile_pic                          6408 non-null   object
#  25  host_identity_verified                        6408 non-null   object
#  26  neighbourhood                                 4819 non-null   object
#  27  neighbourhood_cleansed                        6408 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      6408 non-null   float64
#  30  longitude                                     6408 non-null   float64
#  31  property_type                                 6408 non-null   object
#  32  room_type                                     6408 non-null   object
#  33  accommodates                                  6408 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                6405 non-null   object
#  36  bedrooms                                      6126 non-null   float64
#  37  beds                                          6396 non-null   float64
#  38  amenities                                     6408 non-null   object
#  39  price                                         6408 non-null   object
#  40  minimum_nights                                6408 non-null   int64
#  41  maximum_nights                                6408 non-null   int64
#  42  minimum_minimum_nights                        6407 non-null   float64
#  43  maximum_minimum_nights                        6407 non-null   float64
#  44  minimum_maximum_nights                        6407 non-null   float64
#  45  maximum_maximum_nights                        6407 non-null   float64
#  46  minimum_nights_avg_ntm                        6407 non-null   float64
#  47  maximum_nights_avg_ntm                        6407 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              6408 non-null   object
#  50  availability_30                               6408 non-null   int64
#  51  availability_60                               6408 non-null   int64
#  52  availability_90                               6408 non-null   int64
#  53  availability_365                              6408 non-null   int64
#  54  calendar_last_scraped                         6408 non-null   object
#  55  number_of_reviews                             6408 non-null   int64
#  56  number_of_reviews_ltm                         6408 non-null   int64
#  57  number_of_reviews_l30d                        6408 non-null   int64
#  58  first_review                                  5657 non-null   object
#  59  last_review                                   5657 non-null   object
#  60  review_scores_rating                          5641 non-null   float64
#  61  review_scores_accuracy                        5629 non-null   float64
#  62  review_scores_cleanliness                     5630 non-null   float64
#  63  review_scores_checkin                         5630 non-null   float64
#  64  review_scores_communication                   5630 non-null   float64
#  65  review_scores_location                        5630 non-null   float64
#  66  review_scores_value                           5630 non-null   float64
#  67  license                                       5850 non-null   object
#  68  instant_bookable                              6408 non-null   object
#  69  calculated_host_listings_count                6408 non-null   int64
#  70  calculated_host_listings_count_entire_homes   6408 non-null   int64
#  71  calculated_host_listings_count_private_rooms  6408 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   6408 non-null   int64
#  73  reviews_per_month                             5657 non-null   float64
# dtypes: float64(21), int64(19), object(34)
# memory usage: 3.6+ MB
# None

# %%
#dropping columns containing urls because I am not interested in this data right now
url_cols = [col for col in listings.columns if 'url' in col]
listings.drop(columns = url_cols, inplace = True)

# %%
str_to_length = ['neighborhood_overview','description','host_about']
str_to_boolean=['instant_bookable','host_is_superhost','host_has_profile_pic','host_identity_verified']
to_int = ['host_response_rate','host_acceptance_rate','bathrooms_text','price']
to_category =['room_type','property_type','host_response_time','neighbourhood_cleansed']
to_date=['first_review','last_review']

# %%
#creates column describing the length of neighborhood overview description. These could be turned to boolean values
#if it appears that length of description isn't correlated with price
length_columns = []
for column in listings[str_to_length]:
    listings[str(column)+'_len'] = listings[column].str.len() 
    length_columns.append(str(column)+'_len')

# %%
listings.drop(columns = str_to_length, inplace = True)

# %%
#fills missing values these columns with 0 
listings[length_columns]=listings[length_columns].fillna(value=float(0))

# %%
#it appears that the imported data for neighborhood overview and description length only allowed for 1000 words. 
#While host about allowed for almost 5000
for col in listings[length_columns]:
    print (col)
    print( 'maximum : ' + str(max(listings[col])))
    print ('# max : '+str(len(listings[listings[col]==max(listings[col])])))
    print ('# below max : ' + str(len(listings[listings[col]!=max(listings[col])])))
# Out:
# neighborhood_overview_len
# maximum : 1000.0
# # max : 501
# # below max : 5907
# description_len
# maximum : 1000.0
# # max : 4097
# # below max : 2311
# host_about_len
# maximum : 4499.0
# # max : 1
# # below max : 6407

# %%
#true/false columns were imported as strings 't' or 'f'. This changes them to boolean types
bools={'t':True,'f':False}
for column in listings[str_to_boolean]:
    listings[column] = listings[column].map(bools)

# %%
#cleaning up symbols in strings to prepare to convert to floats
listings['host_response_rate']= listings['host_response_rate'].str.replace('%','')
listings['host_acceptance_rate']=listings['host_acceptance_rate'].str.replace('%','')
listings['bathrooms_text']=listings["bathrooms_text"].str.replace(' bath','')
listings['bathrooms_text']=listings['bathrooms_text'].str.replace('s','')
listings['price']=listings['price'].str.replace('$','')

# %%
#converts numberic string columns to floats
for col in listings[to_int]:
    listings[col]=pd.to_numeric(listings[col],errors = 'coerce')

# %%
#changes date columns to datetime types
for col in listings[to_date]:
    listings[col]=pd.to_datetime(listings[col])

# %%
#converts columns to categories 
for column in listings[to_category]:
    listings[column]=listings[column].astype('category')

# %%
missing_list = listings.columns[listings.isna().any()].tolist()
print(listings[missing_list].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   host_location                 6396 non-null   object
#  1   host_response_time            4801 non-null   category
#  2   host_response_rate            4801 non-null   float64
#  3   host_acceptance_rate          5877 non-null   float64
#  4   host_neighbourhood            5665 non-null   object
#  5   neighbourhood                 4819 non-null   object
#  6   neighbourhood_group_cleansed  0 non-null      float64
#  7   bathrooms                     0 non-null      float64
#  8   bathrooms_text                5637 non-null   float64
#  9   bedrooms                      6126 non-null   float64
#  10  beds                          6396 non-null   float64
#  11  price                         6350 non-null   float64
#  12  minimum_minimum_nights        6407 non-null   float64
#  13  maximum_minimum_nights        6407 non-null   float64
#  14  minimum_maximum_nights        6407 non-null   float64
#  15  maximum_maximum_nights        6407 non-null   float64
#  16  minimum_nights_avg_ntm        6407 non-null   float64
#  17  maximum_nights_avg_ntm        6407 non-null   float64
#  18  calendar_updated              0 non-null      float64
#  19  first_review                  5657 non-null   datetime64[ns]
#  20  last_review                   5657 non-null   datetime64[ns]
#  21  review_scores_rating          5641 non-null   float64
#  22  review_scores_accuracy        5629 non-null   float64
#  23  review_scores_cleanliness     5630 non-null   float64
#  24  review_scores_checkin         5630 non-null   float64
#  25  review_scores_communication   5630 non-null   float64
#  26  review_scores_location        5630 non-null   float64
#  27  review_scores_value           5630 non-null   float64
#  28  license                       5850 non-null   object
#  29  reviews_per_month             5657 non-null   float64
# dtypes: category(1), datetime64[ns](2), float64(23), object(4)
# memory usage: 1.4+ MB
# None

# %%
all_missing = listings.columns[listings.isna().all()].tolist()
print(all_missing)
# Out:
# ['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated']

# %%
listings.drop(columns = all_missing, inplace = True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6408 non-null   int64
#  1   scrape_id                                     6408 non-null   int64
#  2   last_scraped                                  6408 non-null   object
#  3   name                                          6408 non-null   object
#  4   host_id                                       6408 non-null   int64
#  5   host_name                                     6408 non-null   object
#  6   host_since                                    6408 non-null   object
#  7   host_location                                 6396 non-null   object
#  8   host_response_time                            4801 non-null   category
#  9   host_response_rate                            4801 non-null   float64
#  10  host_acceptance_rate                          5877 non-null   float64
#  11  host_is_superhost                             6408 non-null   bool
#  12  host_neighbourhood                            5665 non-null   object
#  13  host_listings_count                           6408 non-null   int64
#  14  host_total_listings_count                     6408 non-null   int64
#  15  host_verifications                            6408 non-null   object
#  16  host_has_profile_pic                          6408 non-null   bool
#  17  host_identity_verified                        6408 non-null   bool
#  18  neighbourhood                                 4819 non-null   object
#  19  neighbourhood_cleansed                        6408 non-null   category
#  20  latitude                                      6408 non-null   float64
#  21  longitude                                     6408 non-null   float64
#  22  property_type                                 6408 non-null   category
#  23  room_type                                     6408 non-null   category
#  24  accommodates                                  6408 non-null   int64
#  25  bathrooms_text                                5637 non-null   float64
#  26  bedrooms                                      6126 non-null   float64
#  27  beds                                          6396 non-null   float64
#  28  amenities                                     6408 non-null   object
#  29  price                                         6350 non-null   float64
#  30  minimum_nights                                6408 non-null   int64
#  31  maximum_nights                                6408 non-null   int64
#  32  minimum_minimum_nights                        6407 non-null   float64
#  33  maximum_minimum_nights                        6407 non-null   float64
#  34  minimum_maximum_nights                        6407 non-null   float64
#  35  maximum_maximum_nights                        6407 non-null   float64
#  36  minimum_nights_avg_ntm                        6407 non-null   float64
#  37  maximum_nights_avg_ntm                        6407 non-null   float64
#  38  has_availability                              6408 non-null   object
#  39  availability_30                               6408 non-null   int64
#  40  availability_60                               6408 non-null   int64
#  41  availability_90                               6408 non-null   int64
#  42  availability_365                              6408 non-null   int64
#  43  calendar_last_scraped                         6408 non-null   object
#  44  number_of_reviews                             6408 non-null   int64
#  45  number_of_reviews_ltm                         6408 non-null   int64
#  46  number_of_reviews_l30d                        6408 non-null   int64
#  47  first_review                                  5657 non-null   datetime64[ns]
#  48  last_review                                   5657 non-null   datetime64[ns]
#  49  review_scores_rating                          5641 non-null   float64
#  50  review_scores_accuracy                        5629 non-null   float64
#  51  review_scores_cleanliness                     5630 non-null   float64
#  52  review_scores_checkin                         5630 non-null   float64
#  53  review_scores_communication                   5630 non-null   float64
#  54  review_scores_location                        5630 non-null   float64
#  55  review_scores_value                           5630 non-null   float64
#  56  license                                       5850 non-null   object
#  57  instant_bookable                              6408 non-null   bool
#  58  calculated_host_listings_count                6408 non-null   int64
#  59  calculated_host_listings_count_entire_homes   6408 non-null   int64
#  60  calculated_host_listings_count_private_rooms  6408 non-null   int64
#  61  calculated_host_listings_count_shared_rooms   6408 non-null   int64
#  62  reviews_per_month                             5657 non-null   float64
#  63  neighborhood_overview_len                     6408 non-null   float64
#  64  description_len                               6408 non-null   float64
#  65  host_about_len                                6408 non-null   float64
# dtypes: bool(4), category(4), datetime64[ns](2), float64(25), int64(19), object(12)
# memory usage: 2.9+ MB

# %%
#I will drop rows with missing prices since this is the target variable.
listings['price'].dropna(inplace= True)
print(listings.shape)
# Out:
# (6408, 66)

# %%
#correlation matrix to quickly see if there are any features with missing values that correlate well with features without missing values.
listings.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col2 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col4 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col6 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col7 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col9 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col10 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col11 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col12 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col13 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col14 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col15 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col16 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col17 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col18 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col19 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col20 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col21 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col22 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col23 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col24 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col25 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col26 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col27 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col28 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col29 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col30 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col31 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col32 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col33 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col34 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col35 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col36 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col37 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col38 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col39 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col40 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col41 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col42 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col43 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col44 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col45 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col46 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row0_col47 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col2 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col5 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col6 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col7 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col9 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col10 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_0a8886f4_1b08_11eb_910d_60f81dd02978row1_col11 {
#             background-color:  #

# %%
#looks like the complete 'accommodates' feature is strongly correlated with number of rooms, bathrooms and beds.

rooms = ['bathrooms_text','bedrooms','beds']
for column in listings[rooms]:
    print(str(column) +': ' +str(listings['accommodates'].corr(listings[column])))
# Out:
# bathrooms_text: 0.7020057448445914
# bedrooms: 0.8662716469848777
# beds: 0.8275110679893758

# %%
#since there is correation, I'll group by 'accommodates' before filling these features witht the average. This might 
#might give me a more accurate representation 
#First I'll double checking to make sure there aren't any zero values or anything really high 
#in 'accommodates' that looks like a mistake

print(listings['accommodates'].unique())
print(listings['accommodates'].hist())
# Out:
# [ 4  3  2  6  7 16 14  5 10  1  8 12 15  9 13 11  0]
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#looks okay so I'll go ahead and fill in the missing values
for column in listings[rooms]:
    listings[column] = listings[column].fillna(listings.groupby('accommodates')[column].transform('mean'))

# %%
#Making column of how many days airbnb has operated as of today's date
print(listings.first_review[:5])
listings["days_active"]=(pd.Timestamp.today() -listings.first_review).dt.days
listings.days_active[:5]
# Out:
# 0   2011-03-07
# 1   2010-04-16
# 2   2010-07-04
# 3   2011-02-16
# 4   2011-03-15
# Name: first_review, dtype: datetime64[ns]
# 0    3525.0
# 1    3850.0
# 2    3771.0
# 3    3544.0
# 4    3517.0
# Name: days_active, dtype: float64

# %%
#May want to limit data to airbnbs that have been operating longer because more people might stay in these each month
#but reviews doesn't look to be that correlated with how often they are booked
print(len(listings))
print(len(listings[listings['days_active']>365]))
print(len(listings[listings['days_active']>180]))
print(listings.days_active.corr(listings.reviews_per_month))
# Out:
# 6408
# 4698
# 5392
# 0.10674731334420666

# %%
listings.drop(columns = ['first_review','last_review'], inplace = True)

# %%
#I wasn't able to look at histograms by running them without separating them into integers and floats for some reason
l_ints = []
l_floats = []
for column, dtype in listings.dtypes.iteritems():
    if dtype == 'int64':
        l_ints.append(column)
    if dtype == 'float64':
        l_floats.append(column)

# %%
listings[l_ints].hist(bins = 10, figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'accommodates'}>,
#         <AxesSubplot:title={'center':'availability_30'}>,
#         <AxesSubplot:title={'center':'availability_365'}>,
#         <AxesSubplot:title={'center':'availability_60'}>],
#        [<AxesSubplot:title={'center':'availability_90'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count_entire_homes'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count_private_rooms'}>],
#        [<AxesSubplot:title={'center':'calculated_host_listings_count_shared_rooms'}>,
#         <AxesSubplot:title={'center':'host_id'}>,
#         <AxesSubplot:title={'center':'host_listings_count'}>,
#         <AxesSubplot:title={'center':'host_total_listings_count'}>],
#        [<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'maximum_nights'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>,
#         <AxesSubplot:title={'center':'number_of_reviews'}>],
#        [<AxesSubplot:title={'center':'number_of_reviews_l30d'}>,
#         <AxesSubplot:title={'center':'number_of_reviews_ltm'}>,
#         <AxesSubplot:title={'center':'scrape_id'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
listings[l_floats].hist(bins=10,figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'bathrooms_text'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'beds'}>,
#         <AxesSubplot:title={'center':'days_active'}>,
#         <AxesSubplot:title={'center':'description_len'}>],
#        [<AxesSubplot:title={'center':'host_about_len'}>,
#         <AxesSubplot:title={'center':'host_acceptance_rate'}>,
#         <AxesSubplot:title={'center':'host_response_rate'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>],
#        [<AxesSubplot:title={'center':'maximum_maximum_nights'}>,
#         <AxesSubplot:title={'center':'maximum_minimum_nights'}>,
#         <AxesSubplot:title={'center':'maximum_nights_avg_ntm'}>,
#         <AxesSubplot:title={'center':'minimum_maximum_nights'}>,
#         <AxesSubplot:title={'center':'minimum_minimum_nights'}>],
#        [<AxesSubplot:title={'center':'minimum_nights_avg_ntm'}>,
#         <AxesSubplot:title={'center':'neighborhood_overview_len'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'review_scores_accuracy'}>,
#         <AxesSubplot:title={'center':'review_scores_checkin'}>],
#        [<AxesSubplot:title={'center':'review_scores_cleanliness'}>,
#         <AxesSubplot:title={'center':'review_scores_communication'}>,
#         <AxesSubplot:title={'center':'review_scores_location'}>,
#         <AxesSubplot:title={'center':'review_scores_rating'}>,
#         <AxesSubplot:title={'center':'review_scores_value'}>],
#        [<AxesSubplot:title={'center':'reviews_per_month'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
#host listings count, looks weird so I'll check it out
print(listings[['name','host_name','host_id','license','host_listings_count']][listings['host_listings_count']>1500])
# Out:
#                                                    name  host_name    host_id  \
# 4055      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 5089      Club La Pension, New Orleans, 1 Bedroom Suite  Christian  194953121
# 5145      Club La Pension, New Orleans, 1 Bedroom Suite  Christian  194953121
# 5146          Ghouling Club La Pension, 1 Bedroom Suite  Christian  194953121
# 5148  The Marquee Resort, New Orleans,1 Bedroom Stan...  Christian  194953121
# 5149   The Marquee Resort, 1 Bedroom Deluxe Sleeps Four  Christian  194953121
# 5150        The Marquee Resort, Huge 1 Bedroom Standard  Christian  194953121
# 5151             The Marquee Resort, 2 Bedroom Standard  Christian  194953121
# 5153          The Marquee Resort, Huge 1 Bedroom Deluxe  Christian  194953121
# 5154        The Marquee Resort, Huge 1 Bedroom Standard  Christian  194953121
# 5155  The Marquee Resort, 1 Bedroom Standard Sleeps Two  Christian  194953121
# 5567       The Bayou's Club La Pension, 2 Bedroom Suite  Christian  194953121
# 5713        Rendezvous at Club La Pension™ -  2 Bedroom  Christian  194953121
# 5720  Classy Club Wyndham Avenue Plaza, 1 Bedroom De...  Christian  194953121
# 5721                  Elegant Club Wyndham Avenue Plaza  Christian  194953121
# 5722            Wyndham Avenue Plaza - 1 Bedroom Deluxe  Christian  194953121
# 5723  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5724  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5725    Classy Club Wyndham Avenue Plaza, Studio Deluxe  Christian  194953121
# 5726   Elegant Club Wyndham Avenue Plaza, Studio Deluxe  Christian  194953121
# 5727  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5888  The Marquee Resort, Commodious 1 Bedroom Standard  Christian  194953121
# 5889    The Marquee Resort, 1 Bedroom Standard Sleeps 2  Christian  194953121
# 5890    The Marquee Resort, Spacious 1 Bedroom Standard  Christian  194953121
# 6257             French Quarter Prime Location Sleeps 4  Christian  194953121
# 6258      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 6259      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 6284          The Marquee - Stunning 1 Bedroom Standard  Christian  194953121
#
#                                                 license  host_listings_count
# 4055  Exempt: This listing is a licensed hotel, mote...                 1916
# 5089  Exempt: This listing is a licensed hotel, mote...                 1916
# 5145  Exempt: This listing is a licensed hotel, mote...                 1916
# 5146  Exempt: This listing is a licensed hotel, mote...                 1916
# 5148  Exempt: This listing is a licensed hotel, mote...                 1916
# 5149  Exempt: This listing is a licensed hotel, mote...                 1916
# 5150  Exempt: This listing is a licensed hotel, mote...                 1916
# 5151  Exempt: This listing is a licensed hotel, mote...                 1916
# 5153  Exempt: This listing is a licensed hotel, mote...                 1916
# 5154  Exempt: This listing is a licensed hotel, mote...                 1916
# 5155  Exempt: This listing is a licensed hotel, mote...                 1916
# 5567  Exempt: This listing is a licensed hotel, mote...                 1916
# 5713  Exempt: This listing is a licensed hotel, mote...                 1916
# 5720  Exempt: This listing is a licensed hotel, mote...                 1916
# 5721  Exempt: This listing is a licensed hotel, mote...                 1916
# 5722  Exempt: This listing is a licensed hotel, mote...                 1916
# 5723  Exempt: This listing is a licensed hotel, mote...                 1916
# 5724  Exempt: This listing is a licensed hotel, mote...                 1916
# 5725  Exempt: This listing is a licensed hotel, mote...                 1916
# 5726  Exempt: This listing is a licensed hotel, mote...                 1916
# 5727  Exempt: This listing is a licensed hotel, mote...                 1916
# 5888  Exempt: This listing is a licensed hotel, mote...                 1916
# 5889  Exempt: This listing is a licensed hotel, mote...                 1916
# 5890  Exempt: This listing is a licensed hotel, mote...                 1916
# 6257  Exempt: This listing is a licensed hotel, mote...                 1916
# 6258  Exempt: This listing is a licensed hotel, mote...                 1916
# 6259  Exempt: This listing is a licensed hotel, mote...                 1916
# 6284  Exempt: This listing is a licensed hotel, mote...                 1916

# %%
print(listings[listings['host_id']==194953121].shape)
print(listings[listings['host_name']=='Christian'].shape)
print(listings[listings['license']=='Exempt: This listing is a licensed hotel, motel, or bed and breakfast'].shape)
#can't see how this host's host_listings_count can be greater than 28. 1125 at the most
# Out:
# (28, 65)
# (35, 65)
# (1125, 65)

# %%
print(listings[['name','host_name','host_id','license','host_listings_count','calculated_host_listings_count']][listings['calculated_host_listings_count']>100])
print(listings[listings['host_name']=='Hosteeva'].shape)
print(listings[listings['host_id']==24831061].shape)
#this column looks to have been determined by host_id so I'll keep it and remove other columns related to number of host listings
# Out:
#                                                  name host_name   host_id  \
# 1115       Spacious 3BR Condo close to French Quarter  Hosteeva  24831061
# 1117         Luxury 4BR Penthouse Near French Quarter  Hosteeva  24831061
# 1119                     Luxury 4BR condo in Downtown  Hosteeva  24831061
# 1240         Lovely 2BR next to City Park by Hosteeva  Hosteeva  24831061
# 1249       Stunning 1BR next to City Park by Hosteeva  Hosteeva  24831061
# ...                                               ...       ...       ...
# 4938                        Luxury Living in Mid City  Hosteeva  24831061
# 5115      Hosteeva | Double on Martin Luther King Jr.  Hosteeva  24831061
# 5122  Hosteeva | 2BR Double Steps to St. Charles Ave.  Hosteeva  24831061
# 5529                     Lovely 3BR next to City Park  Hosteeva  24831061
# 5530                         1812 #3 Luxury 3BR Condo  Hosteeva  24831061
#
#                          license  host_listings_count  \
# 1115  20STR-21055, 20-OSTR-00670                  624
# 1117   20STR-21055, 20-OSTR-0670                  624
# 1119   20STR-21055, 20-OSTR-0670                  624
# 1240   18STR-20431, 20-OSTR-0670                  624
# 1249   18STR-10509, 20-OSTR-0670                  624
# ...                          ...                  ...
# 4938   19STR-09096, 20-OSTR-0670                  624
# 5115   19STR-21847, 20-OSTR-0670                  624
# 5122   19STR-21843, 20-OSTR-0670                  624
# 5529   19STR-12359, 20-OSTR-0670                  624
# 5530   18STR-13759, 20-OSTR-0670                  624
#
#       calculated_host_listings_count
# 1115                             142
# 1117                             142
# 1119                             142
# 1240                             142
# 1249                             142
# ...                              ...
# 4938                             142
# 5115                             142
# 5122                             142
# 5529                             142
# 5530                             142
#
# [142 rows x 6 columns]
# (186, 65)
# (142, 65)

# %%
listings.drop(columns = ['host_listings_count','host_total_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms'],inplace=True)

# %%
#columns related to minimum and maximum nights look strange or repetitive in histograms
#New Orleans defines the length of short-term rentals as rentals as less than 30 days
print(listings[listings['minimum_nights']>29].shape)
print(listings[listings['license']=='Long-term host, exempt from registration'].shape)
listings = listings[listings['license']!='Long-term host, exempt from registration']
# Out:
# (1314, 60)
# (4, 60)

# %%
#there are enough listings with a high minimum nights value to try to figure out a good replacement value rather 
#than deleting them
min_nights = list(listings['minimum_nights'][listings['minimum_nights']>29])
min_nights.sort(reverse = True)
print(min_nights)
# Out:
# [360, 360, 180, 180, 180, 120, 100, 91, 90, 90, 90, 90, 90, 90, 90, 90, 90, 89, 60, 60, 60, 60, 60, 60, 60, 60, 45, 32, 32, 32, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,  ...

# %%
#most listings are 30 nights. They could be listed this way to circumvent some of NOLA's short term rental laws so 
#I'll keep anything 30 nights or fewer.
listings=listings[listings['minimum_nights']<31]

# %%
listings.drop(columns = ['minimum_minimum_nights','maximum_minimum_nights','minimum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm'],inplace = True)

# %%
#creates a column of estimated earnings per month assuming the guests only stayed the minimum nights
listings['lowest_estimate/month']=listings['price']*listings['reviews_per_month']*listings['minimum_nights']
print(listings["lowest_estimate/month"].head())
print(listings['lowest_estimate/month'].mean())
print(listings['lowest_estimate/month'].max())
# Out:
# 0     324.00
# 1     221.40
# 2     550.02
# 3     756.60
# 4    1184.04
# Name: lowest_estimate/month, dtype: float64
# 1178.4588610382598
# 49276.50000000001

# %%
conditions = [(listings['minimum_nights']>5),(listings['minimum_nights']<=5)]
values = [(listings['lowest_estimate/month']),(listings['price']*listings['reviews_per_month']*5)]
listings['middle_estimate/month']=np.select(conditions, values)
print(listings['middle_estimate/month'].head())
print(listings['middle_estimate/month'].mean())
print(listings['middle_estimate/month'].max())
# Out:
# 0     810.0
# 1    1107.0
# 2     916.7
# 3    1261.0
# 4    1973.4
# Name: middle_estimate/month, dtype: float64
# 1817.8910539428734
# 49276.50000000001

# %%
#these seem really high
#I need to check to see if there are rows where number of reviews per month multplied by minimum_nights
#outnumber the number of days in a month 
#I'm going to remove these rows
print(listings[['minimum_nights','reviews_per_month']][(listings['minimum_nights']*listings['reviews_per_month'])>30])
listings = listings[(listings['minimum_nights']*listings['reviews_per_month'])<30]
print(listings['middle_estimate/month'].mean())
print(listings['middle_estimate/month'].max())
print(listings['lowest_estimate/month'].mean())
print(listings['lowest_estimate/month'].max())
# Out:
#       minimum_nights  reviews_per_month
# 12                30               1.29
# 34                30               1.61
# 36                30               1.21
# 40                30               1.67
# 46                30               2.32
# ...              ...                ...
# 4884              30               2.47
# 4910              30               1.42
# 4914              30               1.85
# 5008              30               1.64
# 5980              30               2.12
#
# [400 rows x 2 columns]
# 1390.6043111003485
# 18873.0
# 701.003571483921
# 18873.0

# %%
#these estimates seem pretty high 
#this checks to see if any rows have higher

# %%
#host acceptance rate showed some zero values in histogram
print(len(listings[listings['host_acceptance_rate']==0]))

#I'll go ahead and delete these since there are so few
listings = listings[listings['host_acceptance_rate']>0]
# Out:
# 41

# %%
#deleting listings that have no reviews. I want the model to work on airbnbs that have been 'tested'
print(len(listings[listings['number_of_reviews']==0]))
listings = listings[listings['number_of_reviews'] > 0]
# Out:
# 0

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 6382
# Data columns (total 56 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4809 non-null   int64
#  1   scrape_id                       4809 non-null   int64
#  2   last_scraped                    4809 non-null   object
#  3   name                            4809 non-null   object
#  4   host_id                         4809 non-null   int64
#  5   host_name                       4809 non-null   object
#  6   host_since                      4809 non-null   object
#  7   host_location                   4800 non-null   object
#  8   host_response_time              3956 non-null   category
#  9   host_response_rate              3956 non-null   float64
#  10  host_acceptance_rate            4809 non-null   float64
#  11  host_is_superhost               4809 non-null   bool
#  12  host_neighbourhood              4400 non-null   object
#  13  host_verifications              4809 non-null   object
#  14  host_has_profile_pic            4809 non-null   bool
#  15  host_identity_verified          4809 non-null   bool
#  16  neighbourhood                   3769 non-null   object
#  17  neighbourhood_cleansed          4809 non-null   category
#  18  latitude                        4809 non-null   float64
#  19  longitude                       4809 non-null   float64
#  20  property_type                   4809 non-null   category
#  21  room_type                       4809 non-null   category
#  22  accommodates                    4809 non-null   int64
#  23  bathrooms_text                  4809 non-null   float64
#  24  bedrooms                        4809 non-null   float64
#  25  beds                            4809 non-null   float64
#  26  amenities                       4809 non-null   object
#  27  price                           4776 non-null   float64
#  28  minimum_nights                  4809 non-null   int64
#  29  maximum_nights                  4809 non-null   int64
#  30  has_availability                4809 non-null   object
#  31  availability_30                 4809 non-null   int64
#  32  availability_60                 4809 non-null   int64
#  33  availability_90                 4809 non-null   int64
#  34  availability_365                4809 non-null   int64
#  35  calendar_last_scraped           4809 non-null   object
#  36  number_of_reviews               4809 non-null   int64
#  37  number_of_reviews_ltm           4809 non-null   int64
#  38  number_of_reviews_l30d          4809 non-null   int64
#  39  review_scores_rating            4803 non-null   float64
#  40  review_scores_accuracy          4793 non-null   float64
#  41  review_scores_cleanliness       4793 non-null   float64
#  42  review_scores_checkin           4793 non-null   float64
#  43  review_scores_communication     4793 non-null   float64
#  44  review_scores_location          4793 non-null   float64
#  45  review_scores_value             4793 non-null   float64
#  46  license                         4630 non-null   object
#  47  instant_bookable                4809 non-null   bool
#  48  calculated_host_listings_count  4809 non-null   int64
#  49  reviews_per_month               4809 non-null   float64
#  50  neighborhood_overview_len       4809 non-null   float64
#  51  description_len                 4809 non-null   float64
#  52  host_about_len                  4809 non-null   float64
#  53  days_active                     4809 non-null   float64
#  54  lowest_estimate/month           4776 non-null   float64
#  55  middle_estimate/month           4776 non-null   float64
# dtypes: bool(4), category(4), float64(22), int64(14), object(12)
# memory usage: 1.8+ MB
# None

# %%
listings.drop (columns =['neighbourhood','last_scraped','host_neighbourhood','host_id','host_since','has_availability','calendar_last_scraped','number_of_reviews_ltm','license','host_verifications'],inplace=True)

# %%
#I could probably fill in some more of the missing values, but I'm happy with this amount of data for now. 
print(listings.shape)
listings = listings.dropna()
listings.shape
# Out:
# (4809, 46)
# (3904, 46)

# %%
#prepping amenities colulumn to work with multilabelbinarizer
listings['amenities']=listings['amenities'].map(lambda x: x.lstrip('[').rstrip(']'))
listings['amenities']=listings['amenities'].map(lambda x: x.replace('"',''))

# %%
#creates a new data frame of amenities as separate columns with boolean values
mlb = MultiLabelBinarizer()
amenities_df = pd.DataFrame(mlb.fit_transform(listings['amenities'].str.split(',')),columns=mlb.classes_)
print(amenities_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3904 entries, 0 to 3903
# Columns: 109 entries,  Air conditioning to Wifi
# dtypes: int64(109)
# memory usage: 3.2 MB
# None

# %%
#joins main dataframe with amenities dataframe. This is likely too many features, but I can decide which to drop
#during the EDA phase
listings = listings.reset_index()
listings = listings.join(amenities_df)
listings.drop(columns = 'amenities',inplace=True)

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3904 entries, 0 to 3903
# Columns: 155 entries, index to Wifi
# dtypes: bool(4), category(4), float64(22), int64(122), object(3)
# memory usage: 4.4+ MB
# None

# %%
print(market_value.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   the_geom                                 496 non-null    object
#  1   OBJECTID                                 496 non-null    int64
#  2   geoid                                    496 non-null    int64
#  3   Median Sales Price                       496 non-null    float64
#  4   Coefficient for Variance of Sales Price  496 non-null    float64
#  5   Cluster                                  496 non-null    object
#  6   PercentVacantLandSales                   496 non-null    float64
#  7   PercentSubsidizedRental                  496 non-null    float64
#  8   PercentInspectionViolations              496 non-null    float64
#  9   PercentResidentialAddressesVacant        496 non-null    float64
#  10  PercentVacantLots                        496 non-null    float64
#  11  PercentForeclosure                       496 non-null    float64
#  12  PercentShortTermRentals                  496 non-null    float64
#  13  PercentOwnerOccupied                     496 non-null    float64
#  14  PercentNewConstruction                   496 non-null    float64
#  15  CFCL_ALL16                               496 non-null    int64
#  16  PabnbUhh                                 496 non-null    float64
#  17  Cluster Letter                           446 non-null    object
#  18  PVIOL1617                                496 non-null    float64
#  19  MedianSalesPrice                         0 non-null      float64
#  20  PRENOCONST                               496 non-null    float64
#  21  PctResVac                                496 non-null    float64
#  22  PVACSALES1                               496 non-null    float64
#  23  PHCVPBV_Al                               496 non-null    float64
#  24  PHHOO                                    496 non-null    float64
#  25  PVACDRM_xV                               496 non-null    float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 100.9+ KB
# None

# %%
market_value.hist(bins=10, figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'CFCL_ALL16'}>,
#         <AxesSubplot:title={'center':'Coefficient for Variance of Sales Price'}>,
#         <AxesSubplot:title={'center':'Median Sales Price'}>,
#         <AxesSubplot:title={'center':'MedianSalesPrice'}>,
#         <AxesSubplot:title={'center':'OBJECTID'}>],
#        [<AxesSubplot:title={'center':'PHCVPBV_Al'}>,
#         <AxesSubplot:title={'center':'PHHOO'}>,
#         <AxesSubplot:title={'center':'PRENOCONST'}>,
#         <AxesSubplot:title={'center':'PVACDRM_xV'}>,
#         <AxesSubplot:title={'center':'PVACSALES1'}>],
#        [<AxesSubplot:title={'center':'PVIOL1617'}>,
#         <AxesSubplot:title={'center':'PabnbUhh'}>,
#         <AxesSubplot:title={'center':'PctResVac'}>,
#         <AxesSubplot:title={'center':'PercentForeclosure'}>,
#         <AxesSubplot:title={'center':'PercentInspectionViolations'}>],
#        [<AxesSubplot:title={'center':'PercentNewConstruction'}>,
#         <AxesSubplot:title={'center':'PercentOwnerOccupied'}>,
#         <AxesSubplot:title={'center':'PercentResidentialAddressesVacant'}>,
#         <AxesSubplot:title={'center':'PercentShortTermRentals'}>,
#         <AxesSubplot:title={'center':'PercentSubsidizedRental'}>],
#        [<AxesSubplot:title={'center':'PercentVacantLandSales'}>,
#         <AxesSubplot:title={'center':'PercentVacantLots'}>,
#         <AxesSubplot:title={'center':'geoid'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#not sure what all of these categories are 
#I will keep most of them for EDA
#but 'MedianSalesPrice' is empty/repeat and 'PctResVac' is a repeat 
market_value.drop(columns = ['MedianSalesPrice','PctResVac'], inplace = True)

# %%
#converting listings to geodataframe in order to merge with market value data via gps coordinates
gdf_listings = gpd.GeoDataFrame(listings,   geometry=gpd.points_from_xy(listings.longitude, listings.latitude))

# %%
#changing the_geom column of market_value to correct type for geodataframe geometry column
market_value['geometry'] = market_value['the_geom'].apply(wkt.loads)

# %%
#converting market_value to geodataframe 
m_value_gpd = gpd.GeoDataFrame(market_value, geometry = market_value['geometry'])

# %%
#joining based on gps coordinates
sjoined_listings = gpd.sjoin(m_value_gpd, gdf_listings, op= 'contains' )

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   the_geom  867 non-null    object
#  1   OBJECTID  883 non-null    int64
#  2   Name      883 non-null    object
#  3   Segment   883 non-null    object
#  4   Type      883 non-null    object
#  5   Address   878 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 41.5+ KB

# %%
print(restaurants[restaurants['Address'].duplicated()].shape)
print(restaurants[restaurants['Address']=='3901 BANKS  ST'])

#there are some addresses litsing multiple restaurants because of a business having retail and dining licenses
#some addresses contain names of previous restaurants and current restaurants
#some addresses are large enough to hold several retaurants
#without spending a lot of time researching this, I think its safe to remove duplicate addresses.  Even it is a food
#court or something, it will be counted as one restaurant. 
restaurants.drop_duplicates(subset = ['Address'], inplace = True)
# Out:
# (48, 6)
#                                      the_geom  OBJECTID  \
# 687  POINT (-90.100966696726 29.970772242784)        37
# 742  POINT (-90.100966696726 29.970772242784)       450
#
#                       Name        Segment           Type         Address
# 687  MONA'S PITA BREAD INC  Culinary Arts  Food Products  3901 BANKS  ST
# 742            MONA'S CAFE  Culinary Arts     Restaurant  3901 BANKS  ST

# %%
#dropped ojectid from restaurants before merging since it is a duplicate column name
restaurants.drop(columns = 'OBJECTID', inplace = True)
restaurants.dropna(inplace = True)
restaurants['the_geom']=restaurants['the_geom'].apply(wkt.loads)
restaurants_gpd = gpd.GeoDataFrame(restaurants, geometry = 'the_geom')

# %%
#joined restaurants to nieghborhoods grouped by the number of restaurants in the neighborhood

restaurants_neighborhoods=gpd.sjoin(m_value_gpd, restaurants_gpd, op='contains')

#create dataframe of restaurants counts grouped by 'geoid' which is the district they're in
restaurants_neighborhoods = restaurants_neighborhoods.groupby('geoid').Name.agg('count').reset_index()

# %%
#rename

restaurants_neighborhoods.rename(columns = {'Name':'Restaurant_Count'}, inplace = True)

# %%
#this is a left join on geoid so that restaurants info will show number of restaurants per discrict
sjoined_listings = pd.merge(sjoined_listings,restaurants_neighborhoods,how = 'left', left_on = 'geoid', right_on = 'geoid')

# %%
sjoined_listings.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3904 entries, 0 to 3903
# Columns: 182 entries, the_geom to Restaurant_Count
# dtypes: bool(4), category(4), float64(41), geometry(1), int64(126), object(6)
# memory usage: 5.2+ MB

# %%
#this shows that there are multiple geoids in each neighborhood
print(len(sjoined_listings.neighbourhood_cleansed.unique()))

len(sjoined_listings.geoid.unique())
# Out:
# 68
# 387

# %%
#this shows that there are geoids in neighborhoods with no restaurants.
neighborhoods = sjoined_listings.groupby(['neighbourhood_cleansed','geoid']).Restaurant_Count.agg('max')
neighborhoods
# Out:
# neighbourhood_cleansed  geoid
# Algiers Point           220710001001    1.0
#                         220710001002    NaN
#                         220710001003    3.0
#                         220710002001    NaN
#                         220710002002    NaN
#                                        ...
# Whitney                 220710143003    NaN
#                         220710144001    NaN
#                         220710144002    NaN
#                         220710144003    NaN
#                         220710145001    NaN
# Name: Restaurant_Count, Length: 27477, dtype: float64

# %%
#this left joins neighborhoods to main dataframe so that each entry
#has a column that shows how many restaurants are in its neighborhood
neighborhoods = neighborhoods.reset_index()
neighborhoods = neighborhoods.groupby('neighbourhood_cleansed').Restaurant_Count.agg('sum')
neighborhoods = neighborhoods.to_frame().reset_index()
neighborhoods.rename(columns = {'Restaurant_Count':'neighborhood_restaurants'},inplace=True)
geolistings = pd.merge(sjoined_listings,neighborhoods,how = 'left', left_on = 'neighbourhood_cleansed', right_on = 'neighbourhood_cleansed')

# %%
#this is just some code to show me which neighborhoods the data shows no restaurants for
#These neighborhoods are industrial, highly suburban or very impovershed to it looks reasonable to me
geolistings.update(geolistings[['Restaurant_Count','neighborhood_restaurants']].fillna(0))
print(geolistings.shape)
print(len(geolistings[geolistings['neighborhood_restaurants']>0]))
group = geolistings[['neighbourhood_cleansed','neighborhood_restaurants']].groupby('neighbourhood_cleansed').neighborhood_restaurants.agg('max')
group = group.reset_index()

print(group.info())
print(group[group['neighborhood_restaurants'].isna()])
print(group[group['neighborhood_restaurants']==0])
# Out:
# (3904, 183)
# 3826
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   neighbourhood_cleansed    71 non-null     category
#  1   neighborhood_restaurants  68 non-null     float64
# dtypes: category(1), float64(1)
# memory usage: 3.8 KB
# None
#    neighbourhood_cleansed  neighborhood_restaurants
# 31    Lake Terrace & Oaks                       NaN
# 66        Village De Lest                       NaN
# 68       West Lake Forest                       NaN
#        neighbourhood_cleansed  neighborhood_restaurants
# 2                B. W. Cooper                       0.0
# 13                      Dixon                       0.0
# 18                Fischer Dev                       0.0
# 19               Florida Area                       0.0
# 24             Gentilly Woods                       0.0
# 26                 Hollygrove                       0.0
# 30             Lake Catherine                       0.0
# 46  New Aurora - English Turn                       0.0
# 48              Pines Village                       0.0
# 49               Plum Orchard                       0.0
# 50         Pontchartrain Park                       0.0
# 55           St. Bernard Area                       0.0
# 63            U.S. Naval Base                       0.0
# 70                    Whitney                       0.0

# %%
geolistings.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3904 entries, 0 to 3903
# Columns: 183 entries, the_geom to neighborhood_restaurants
# dtypes: bool(4), category(4), float64(42), geometry(1), int64(126), object(6)
# memory usage: 5.3+ MB

# %%
geolistings.plot('neighborhood_restaurants',figsize=(20,16),legend = True)
# Out:
# <AxesSubplot:>

# %%
ints = []
floats = []
for column, dtype in geolistings.dtypes.iteritems():
    if dtype == 'int64':
        ints.append(column)
    if dtype == 'float64':
        floats.append(column)

# %%
geolistings[ints].hist(bins = 10, figsize= (50,50))
#a lot of these look strange because of all the boolean amenities columns
#these should be taken care of in the EDA step
# Out:
# array([[<AxesSubplot:title={'center':' Air conditioning'}>,
#         <AxesSubplot:title={'center':' BBQ grill'}>,
#         <AxesSubplot:title={'center':' Baby bath'}>,
#         <AxesSubplot:title={'center':' Baby monitor'}>,
#         <AxesSubplot:title={'center':' Babysitter recommendations'}>,
#         <AxesSubplot:title={'center':' Baking sheet'}>,
#         <AxesSubplot:title={'center':' Barbecue utensils'}>,
#         <AxesSubplot:title={'center':' Bathroom essentials'}>,
#         <AxesSubplot:title={'center':' Bathtub'}>,
#         <AxesSubplot:title={'center':' Beach essentials'}>,
#         <AxesSubplot:title={'center':' Beachfront'}>],
#        [<AxesSubplot:title={'center':' Bed linens'}>,
#         <AxesSubplot:title={'center':' Bedroom comforts'}>,
#         <AxesSubplot:title={'center':' Bread maker'}>,
#         <AxesSubplot:title={'center':' Breakfast'}>,
#         <AxesSubplot:title={'center':' Building staff'}>,
#         <AxesSubplot:title={'center':' Cable TV'}>,
#         <AxesSubplot:title={'center':' Carbon monoxide alarm'}>,
#         <AxesSubplot:title={'center':' Changing table'}>,
#         <AxesSubplot:title={'center':' Children\\u2019s books and toys'}>,
#         <AxesSubplot:title={'center':' Children\\u2019s dinnerware'}>,
#         <AxesSubplot:title={'center':' Cleaning before checkout'}>],
#        [<AxesSubplot:title={'center':' Coffee maker'}>,
#         <AxesSubplot:title={'center':' Cooking basics'}>,
#         <AxesSubplot:title={'center':' Crib'}>,
#         <AxesSubplot:title={'center':' Dishes and silverware'}>,
#         <AxesSubplot:title={'center':' Dishwasher'}>,
#         <AxesSubplot:title={'center':' Dryer'}>,
#         <AxesSubplot:title={'center':' Elevator'}>,
#         <AxesSubplot:title={'center':' Essentials'}>,
#         <AxesSubplot:title={'center':' Ethernet connection'}>,
#         <AxesSubplot:title={'center':' Extra pillows and blankets'}>,
#         <AxesSubplot:title={'center':' Fire extinguisher'}>],
#        [<AxesSubplot:title={'center':' Fireplace guards'}>,
#         <AxesSubplot:title={'center':' First aid kit'}>,
#         <AxesSubplot:title={'center':' Free parking on premises'}>,
#         <AxesSubplot:title={'center':' Free street parking'}>,
#         <AxesSubplot:title={'center':' Full kitchen'}>,
#         <AxesSubplot:title={'center':' Game console'}>,
#         <AxesSubplot:title={'center':' Garden or backyard'}>,
#         <AxesSubplot:title={'center':' Gym'}>,
#         <AxesSubplot:title={'center':' Hair dryer'}>,
#         <AxesSubplot:title={'center':' Hangers'}>,
#         <AxesSubplot:title={'center':' Heating'}>],
#        [<AxesSubplot:title={'center':' High chair'}>,
#         <AxesSubplot:title={'center':' Host greets you'}>,
#         <AxesSubplot:title={'center':' Hot tub'}>,
#         <AxesSubplot:title={'center':' Hot water'}>,
#         <AxesSubplot:title={'center':' Indoor fireplace'}>,
#         <AxesSubplot:title={'center':' Iron'}>,
#         <AxesSubplot:title={'center':' Keypad'}>,
#         <AxesSubplot:title={'center':' Kitchen'}>,
#         <AxesSubplot:title={'center':' Kitchenette'}>,
#         <AxesSubplot:title={'center':' Lake access'}>,
#         <AxesSubplot:title={'center':' Laptop-friendly workspace'}>],
#        [<AxesSubplot:title={'center':' Lock on bedroom door'}>,
#         <AxesSubplot:title={'center':' Lockbox'}>,
#         <AxesSubplot:title={'center':' Long term stays allowed'}>,
#         <AxesSubplot:title={'center':' Luggage dropoff allowed'}>,
#         <AxesSubplot:title={'center':' Microwave'}>,
#         <AxesSubplot:title={'center':' Outlet covers'}>,
#         <AxesSubplot:title={'center':' Oven'}>,
#         <AxesSubplot:title={'center':' Pack \\u2019n Play/travel crib'}>,
#         <AxesSubplot:title={'center':' Paid parking off premises'}>,
#         <AxesSubplot:title={'center':' Paid parking on premises'}>,
#         <AxesSubplot:title={'center':' Patio or balcony'}>],
#        [<AxesSubplot:title={'center':' Pets allowed'}>,
#         <AxesSubplot:title={'center':' Piano'}>,
#         <AxesSubplot:title={'center':' Pocket wifi'}>,
#         <AxesSubplot:title={'center':' Pool'}>,
#         <AxesSubplot:title={'center':' Pool toys'}>,
#         <AxesSubplot:title={'center':' Private entrance'}>,
#         <AxesSubplot:title={'center':' Private hot tub'}>,
#         <AxesSubplot:title={'center':' Private living room'}>,
#         <AxesSubplot:title={'center':' Refrigerator'}>,
#         <AxesSubplot:title={'center':' Room-darkening shades'}>,
#         <AxesSubplot:title={'center':' Self check-in'}>],
#        [<AxesSubplot:title={'center':' Shampoo'}>,
#         <AxesSubplot:title={'center':' Shared hot tub'}>,
#         <AxesSubplot:title={'center':' Shower gel'}>,
#         <AxesSubplot:title={'center':' Single level home'}>,
#         <AxesSubplot:title={'center':' Ski-in/Ski-out'}>,
#         <AxesSubplot:title={'center':' Smart lock'}>,
#         <AxesSubplot:title={'center':' Smoke alarm'}>,
#         <AxesSubplot:title={'center':' Smoking allowed'}>,
#         <AxesSubplot:title={'center':' Stair gates'}>,
#         <AxesSubplot:title={'center':' Stove'}>,
#         <AxesSubplot:title={'center':' Suitable for events'}>],
#        [<AxesSubplot:title={'center':' TV'}>,
#         <AxesSubplot:title={'center':' Table corner guards'}>,
#         <AxesSubplot:title={'center':' Washer'}>,
#         <AxesSubplot:title={'center':' Waterfront'}>,
#         <AxesSubplot:title={'center':' Wifi'}>,
#         <AxesSubplot:title={'center':' Window guards'}>,
#         <AxesSubplot:title={'center':'Air conditioning'}>,
#         <AxesSubplot:title={'center':'CFCL_ALL16'}>,
#         <AxesSubplot:title={'center':'Cleaning before checkout'}>,
#         <AxesSubplot:title={'center':'Coffee maker'}>,
#         <AxesSubplot:title={'center':'EV charger'}>],
#        [<AxesSubplot:title={'center':'Essentials'}>,
#         <AxesSubplot:title={'center':'Ethernet connection'}>,
#         <AxesSubplot:title={'center':'Hair dryer'}>,
#         <AxesSubplot:title={'center':'Hot tub'}>,
#         <AxesSubplot:title={'center':'Hot water'}>,
#         <AxesSubplot:title={'center':'Laptop-friendly workspace'}>,
#         <AxesSubplot:title={'center':'Lockbox'}>,
#         <AxesSubplot:title={'center':'Long term stays allowed'}>,
#         <AxesSubplot:title={'center':'OBJECTID'}>,
#         <AxesSubplot:title={'center':'Paid parking off premises'}>,
#         <AxesSubplot:title={'center':'Shampoo'}>],
#        [<AxesSubplot:title={'center':'Wifi'}>,
#         <AxesSubplot:title={'center':'accommodates'}>,
#         <AxesSubplot:title={'center':'availability_30'}>,
#         <AxesSubplot:title={'center':'availability_365'}>,
#         <AxesSubplot:title={'center':'availability_60'}>,
#         <AxesSubplot:title={'center':'availability_90'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count'}>,
#         <AxesSubplot:title={'center':'geoid'}>,
#         <AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'index_right'}>],
#        [<AxesSubplot:title={'center':'maximum_nights'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>,
#         <AxesSubplot:title={'center':'number_of_reviews'}>,
#         <AxesSubplot:title={'center':'number_of_reviews_l30d'}>,
#         <AxesSubplot:title={'center':'scrape_id'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
geolistings[floats].hist(bins = 10, figsize= (50,50))
# Out:
# array([[<AxesSubplot:title={'center':'Coefficient for Variance of Sales Price'}>,
#         <AxesSubplot:title={'center':'Median Sales Price'}>,
#         <AxesSubplot:title={'center':'PHCVPBV_Al'}>,
#         <AxesSubplot:title={'center':'PHHOO'}>,
#         <AxesSubplot:title={'center':'PRENOCONST'}>,
#         <AxesSubplot:title={'center':'PVACDRM_xV'}>],
#        [<AxesSubplot:title={'center':'PVACSALES1'}>,
#         <AxesSubplot:title={'center':'PVIOL1617'}>,
#         <AxesSubplot:title={'center':'PabnbUhh'}>,
#         <AxesSubplot:title={'center':'PercentForeclosure'}>,
#         <AxesSubplot:title={'center':'PercentInspectionViolations'}>,
#         <AxesSubplot:title={'center':'PercentNewConstruction'}>],
#        [<AxesSubplot:title={'center':'PercentOwnerOccupied'}>,
#         <AxesSubplot:title={'center':'PercentResidentialAddressesVacant'}>,
#         <AxesSubplot:title={'center':'PercentShortTermRentals'}>,
#         <AxesSubplot:title={'center':'PercentSubsidizedRental'}>,
#         <AxesSubplot:title={'center':'PercentVacantLandSales'}>,
#         <AxesSubplot:title={'center':'PercentVacantLots'}>],
#        [<AxesSubplot:title={'center':'Restaurant_Count'}>,
#         <AxesSubplot:title={'center':'bathrooms_text'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'beds'}>,
#         <AxesSubplot:title={'center':'days_active'}>,
#         <AxesSubplot:title={'center':'description_len'}>],
#        [<AxesSubplot:title={'center':'host_about_len'}>,
#         <AxesSubplot:title={'center':'host_acceptance_rate'}>,
#         <AxesSubplot:title={'center':'host_response_rate'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'lowest_estimate/month'}>],
#        [<AxesSubplot:title={'center':'middle_estimate/month'}>,
#         <AxesSubplot:title={'center':'neighborhood_overview_len'}>,
#         <AxesSubplot:title={'center':'neighborhood_restaurants'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'review_scores_accuracy'}>,
#         <AxesSubplot:title={'center':'review_scores_checkin'}>],
#        [<AxesSubplot:title={'center':'review_scores_cleanliness'}>,
#         <AxesSubplot:title={'center':'review_scores_communication'}>,
#         <AxesSubplot:title={'center':'review_scores_location'}>,
#         <AxesSubplot:title={'center':'review_scores_rating'}>,
#         <AxesSubplot:title={'center':'review_scores_value'}>,
#         <AxesSubplot:title={'center':'reviews_per_month'}>]], dtype=object)

# %% [markdown]
# I think the data is clean enough for EDA.  There will definitely be features removed after looking at it.
# I'm not sure if the target feature will be price per night.
# I'd rather make a model that can estimate how much an owner can make per month depending on controllable factors.
