# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely import wkt
from matplotlib import pyplot
import descartes
import seaborn as sns
import datetime as dt
#import geoplot as geoplot

# %%
#create pandas dataframe of datasets
listings = pd.read_csv('../data/raw/listings.csv')
market_value = pd.read_csv('../data/raw/Market_Value_Analysis__2018_data.csv', index_col = False)
restaurants = pd.read_csv('../data/raw/Culinary_Arts_data.csv', index_col = False)

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  10291  https://www.airbnb.com/rooms/10291  20200909145511   2020-09-10
# 1  19091  https://www.airbnb.com/rooms/19091  20200909145511   2020-09-10
# 2  26834  https://www.airbnb.com/rooms/26834  20200909145511   2020-09-09
# 3  71624  https://www.airbnb.com/rooms/71624  20200909145511   2020-09-10
# 4  74498  https://www.airbnb.com/rooms/74498  20200909145511   2020-09-10
#
#                                   name  \
# 0        Spacious Cottage in Mid-City!
# 1       Fully Furnished Cozy Apartment
# 2     Maison Mandeville in the Marigny
# 3   Ravenwood Manor (Historic Bywater)
# 4  Maison Marais 1: Large Local Living
#
#                                          description  \
# 0  <b>The space</b><br />Spacious house located i...
# 1  CITY OF NEW ORLEANS STR LICENSE PERMIT NUMBER:...
# 2  <b>The space</b><br />Charming shotgun apartme...
# 3  You are in for a very unique stay in a neighbo...
# 4  Maison Marais 1 is a stylish one-bedroom apart...
#
#                                neighborhood_overview  \
# 0  Navarre is a quiet and quaint neighborhood tha...
# 1  NorthWest Carrollton, where this apartment is ...
# 2                                                NaN
# 3  Ours is a neighborhood made up of artists, mus...
# 4  This is a vibrant, diverse neighborhood of mos...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/99566384/fd1d...    31004
# 1  https://a0.muscache.com/pictures/a5fdfd3b-5d81...    72880
# 2  https://a0.muscache.com/pictures/505025/bee98a...   114452
# 3  https://a0.muscache.com/pictures/37488608/8cc1...   367223
# 4  https://a0.muscache.com/pictures/73591836/a1f5...   391462
#
#                                    host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/31004  ...                        10.0
# 1   https://www.airbnb.com/users/show/72880  ...                        10.0
# 2  https://www.airbnb.com/users/show/114452  ...                        10.0
# 3  https://www.airbnb.com/users/show/367223  ...                        10.0
# 4  https://www.airbnb.com/users/show/391462  ...                        10.0
#
#   review_scores_location review_scores_value  \
# 0                   10.0                10.0
# 1                   10.0                10.0
# 2                   10.0                10.0
# 3                   10.0                10.0
# 4                   10.0                10.0
#
#                                              license instant_bookable  \
# 0                          19STR-08424, 19-OSTR-0313                f
# 1                          17STR-08877, 20-OSTR-0105                t
# 2                          19STR-10811, 20-OSTR-0389                f
# 3                                        17STR-08285                f
# 4  Exempt: This listing is a licensed hotel, mote...                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              1                                           1
# 3                              1                                           1
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.08
# 1                                           0              3.69
# 2                                           0              2.06
# 3                                           0              1.94
# 4                                           0              4.29
#
# [5 rows x 74 columns]

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6408 non-null   int64
#  1   listing_url                                   6408 non-null   object
#  2   scrape_id                                     6408 non-null   int64
#  3   last_scraped                                  6408 non-null   object
#  4   name                                          6408 non-null   object
#  5   description                                   6383 non-null   object
#  6   neighborhood_overview                         4819 non-null   object
#  7   picture_url                                   6408 non-null   object
#  8   host_id                                       6408 non-null   int64
#  9   host_url                                      6408 non-null   object
#  10  host_name                                     6408 non-null   object
#  11  host_since                                    6408 non-null   object
#  12  host_location                                 6396 non-null   object
#  13  host_about                                    4226 non-null   object
#  14  host_response_time                            4801 non-null   object
#  15  host_response_rate                            4801 non-null   object
#  16  host_acceptance_rate                          5877 non-null   object
#  17  host_is_superhost                             6408 non-null   object
#  18  host_thumbnail_url                            6408 non-null   object
#  19  host_picture_url                              6408 non-null   object
#  20  host_neighbourhood                            5665 non-null   object
#  21  host_listings_count                           6408 non-null   int64
#  22  host_total_listings_count                     6408 non-null   int64
#  23  host_verifications                            6408 non-null   object
#  24  host_has_profile_pic                          6408 non-null   object
#  25  host_identity_verified                        6408 non-null   object
#  26  neighbourhood                                 4819 non-null   object
#  27  neighbourhood_cleansed                        6408 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      6408 non-null   float64
#  30  longitude                                     6408 non-null   float64
#  31  property_type                                 6408 non-null   object
#  32  room_type                                     6408 non-null   object
#  33  accommodates                                  6408 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                6405 non-null   object
#  36  bedrooms                                      6126 non-null   float64
#  37  beds                                          6396 non-null   float64
#  38  amenities                                     6408 non-null   object
#  39  price                                         6408 non-null   object
#  40  minimum_nights                                6408 non-null   int64
#  41  maximum_nights                                6408 non-null   int64
#  42  minimum_minimum_nights                        6407 non-null   float64
#  43  maximum_minimum_nights                        6407 non-null   float64
#  44  minimum_maximum_nights                        6407 non-null   float64
#  45  maximum_maximum_nights                        6407 non-null   float64
#  46  minimum_nights_avg_ntm                        6407 non-null   float64
#  47  maximum_nights_avg_ntm                        6407 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              6408 non-null   object
#  50  availability_30                               6408 non-null   int64
#  51  availability_60                               6408 non-null   int64
#  52  availability_90                               6408 non-null   int64
#  53  availability_365                              6408 non-null   int64
#  54  calendar_last_scraped                         6408 non-null   object
#  55  number_of_reviews                             6408 non-null   int64
#  56  number_of_reviews_ltm                         6408 non-null   int64
#  57  number_of_reviews_l30d                        6408 non-null   int64
#  58  first_review                                  5657 non-null   object
#  59  last_review                                   5657 non-null   object
#  60  review_scores_rating                          5641 non-null   float64
#  61  review_scores_accuracy                        5629 non-null   float64
#  62  review_scores_cleanliness                     5630 non-null   float64
#  63  review_scores_checkin                         5630 non-null   float64
#  64  review_scores_communication                   5630 non-null   float64
#  65  review_scores_location                        5630 non-null   float64
#  66  review_scores_value                           5630 non-null   float64
#  67  license                                       5850 non-null   object
#  68  instant_bookable                              6408 non-null   object
#  69  calculated_host_listings_count                6408 non-null   int64
#  70  calculated_host_listings_count_entire_homes   6408 non-null   int64
#  71  calculated_host_listings_count_private_rooms  6408 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   6408 non-null   int64
#  73  reviews_per_month                             5657 non-null   float64
# dtypes: float64(21), int64(19), object(34)
# memory usage: 3.6+ MB
# None

# %%
#dropping columns containing urls because I am not interested in this data right now
url_cols = [col for col in listings.columns if 'url' in col]
listings.drop(columns = url_cols, inplace = True)

# %%
str_to_length = ['neighborhood_overview','description','host_about']
str_to_boolean=['instant_bookable','host_is_superhost','host_has_profile_pic','host_identity_verified']
to_int = ['host_response_rate','host_acceptance_rate','bathrooms_text','price']
to_category =['room_type','property_type','host_response_time','neighbourhood_cleansed']
to_date=['first_review','last_review']

# %%
#true/false columns were imported as strings 't' or 'f'. This changes them to boolean types
bools={'t':True,'f':False}
for column in listings[str_to_boolean]:
    listings[column] = listings[column].map(bools)

# %%
#cleaning up symbols in strings to prepare to convert to floats
listings['host_response_rate']= listings['host_response_rate'].str.replace('%','')
listings['host_acceptance_rate']=listings['host_acceptance_rate'].str.replace('%','')
listings['bathrooms_text']=listings["bathrooms_text"].str.replace(' bath','')
listings['bathrooms_text']=listings['bathrooms_text'].str.replace('s','')
listings['price']=listings['price'].str.replace('$','')

# %%
#converts numeric string columns to floats
for col in listings[to_int]:
    listings[col]=pd.to_numeric(listings[col],errors = 'coerce')

# %%
#changes date columns to datetime types
for col in listings[to_date]:
    listings[col]=pd.to_datetime(listings[col])

# %%
#converts columns to categories 
for column in listings[to_category]:
    listings[column]=listings[column].astype('category')

# %%
missing_list = listings.columns[listings.isna().any()].tolist()
print(listings[missing_list].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   description                   6383 non-null   object
#  1   neighborhood_overview         4819 non-null   object
#  2   host_location                 6396 non-null   object
#  3   host_about                    4226 non-null   object
#  4   host_response_time            4801 non-null   category
#  5   host_response_rate            4801 non-null   float64
#  6   host_acceptance_rate          5877 non-null   float64
#  7   host_neighbourhood            5665 non-null   object
#  8   neighbourhood                 4819 non-null   object
#  9   neighbourhood_group_cleansed  0 non-null      float64
#  10  bathrooms                     0 non-null      float64
#  11  bathrooms_text                5637 non-null   float64
#  12  bedrooms                      6126 non-null   float64
#  13  beds                          6396 non-null   float64
#  14  price                         6350 non-null   float64
#  15  minimum_minimum_nights        6407 non-null   float64
#  16  maximum_minimum_nights        6407 non-null   float64
#  17  minimum_maximum_nights        6407 non-null   float64
#  18  maximum_maximum_nights        6407 non-null   float64
#  19  minimum_nights_avg_ntm        6407 non-null   float64
#  20  maximum_nights_avg_ntm        6407 non-null   float64
#  21  calendar_updated              0 non-null      float64
#  22  first_review                  5657 non-null   datetime64[ns]
#  23  last_review                   5657 non-null   datetime64[ns]
#  24  review_scores_rating          5641 non-null   float64
#  25  review_scores_accuracy        5629 non-null   float64
#  26  review_scores_cleanliness     5630 non-null   float64
#  27  review_scores_checkin         5630 non-null   float64
#  28  review_scores_communication   5630 non-null   float64
#  29  review_scores_location        5630 non-null   float64
#  30  review_scores_value           5630 non-null   float64
#  31  license                       5850 non-null   object
#  32  reviews_per_month             5657 non-null   float64
# dtypes: category(1), datetime64[ns](2), float64(23), object(7)
# memory usage: 1.6+ MB
# None

# %%
all_missing = listings.columns[listings.isna().all()].tolist()
print(all_missing)
# Out:
# ['neighbourhood_group_cleansed', 'bathrooms', 'calendar_updated']

# %%
listings.drop(columns = all_missing, inplace = True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6408 entries, 0 to 6407
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6408 non-null   int64
#  1   scrape_id                                     6408 non-null   int64
#  2   last_scraped                                  6408 non-null   object
#  3   name                                          6408 non-null   object
#  4   description                                   6383 non-null   object
#  5   neighborhood_overview                         4819 non-null   object
#  6   host_id                                       6408 non-null   int64
#  7   host_name                                     6408 non-null   object
#  8   host_since                                    6408 non-null   object
#  9   host_location                                 6396 non-null   object
#  10  host_about                                    4226 non-null   object
#  11  host_response_time                            4801 non-null   category
#  12  host_response_rate                            4801 non-null   float64
#  13  host_acceptance_rate                          5877 non-null   float64
#  14  host_is_superhost                             6408 non-null   bool
#  15  host_neighbourhood                            5665 non-null   object
#  16  host_listings_count                           6408 non-null   int64
#  17  host_total_listings_count                     6408 non-null   int64
#  18  host_verifications                            6408 non-null   object
#  19  host_has_profile_pic                          6408 non-null   bool
#  20  host_identity_verified                        6408 non-null   bool
#  21  neighbourhood                                 4819 non-null   object
#  22  neighbourhood_cleansed                        6408 non-null   category
#  23  latitude                                      6408 non-null   float64
#  24  longitude                                     6408 non-null   float64
#  25  property_type                                 6408 non-null   category
#  26  room_type                                     6408 non-null   category
#  27  accommodates                                  6408 non-null   int64
#  28  bathrooms_text                                5637 non-null   float64
#  29  bedrooms                                      6126 non-null   float64
#  30  beds                                          6396 non-null   float64
#  31  amenities                                     6408 non-null   object
#  32  price                                         6350 non-null   float64
#  33  minimum_nights                                6408 non-null   int64
#  34  maximum_nights                                6408 non-null   int64
#  35  minimum_minimum_nights                        6407 non-null   float64
#  36  maximum_minimum_nights                        6407 non-null   float64
#  37  minimum_maximum_nights                        6407 non-null   float64
#  38  maximum_maximum_nights                        6407 non-null   float64
#  39  minimum_nights_avg_ntm                        6407 non-null   float64
#  40  maximum_nights_avg_ntm                        6407 non-null   float64
#  41  has_availability                              6408 non-null   object
#  42  availability_30                               6408 non-null   int64
#  43  availability_60                               6408 non-null   int64
#  44  availability_90                               6408 non-null   int64
#  45  availability_365                              6408 non-null   int64
#  46  calendar_last_scraped                         6408 non-null   object
#  47  number_of_reviews                             6408 non-null   int64
#  48  number_of_reviews_ltm                         6408 non-null   int64
#  49  number_of_reviews_l30d                        6408 non-null   int64
#  50  first_review                                  5657 non-null   datetime64[ns]
#  51  last_review                                   5657 non-null   datetime64[ns]
#  52  review_scores_rating                          5641 non-null   float64
#  53  review_scores_accuracy                        5629 non-null   float64
#  54  review_scores_cleanliness                     5630 non-null   float64
#  55  review_scores_checkin                         5630 non-null   float64
#  56  review_scores_communication                   5630 non-null   float64
#  57  review_scores_location                        5630 non-null   float64
#  58  review_scores_value                           5630 non-null   float64
#  59  license                                       5850 non-null   object
#  60  instant_bookable                              6408 non-null   bool
#  61  calculated_host_listings_count                6408 non-null   int64
#  62  calculated_host_listings_count_entire_homes   6408 non-null   int64
#  63  calculated_host_listings_count_private_rooms  6408 non-null   int64
#  64  calculated_host_listings_count_shared_rooms   6408 non-null   int64
#  65  reviews_per_month                             5657 non-null   float64
# dtypes: bool(4), category(4), datetime64[ns](2), float64(22), int64(19), object(15)
# memory usage: 2.9+ MB

# %%
#I will drop rows with missing prices since this is the target variable.
listings.dropna(subset = ['price'], inplace = True)
print(listings.shape)
# Out:
# (6350, 66)

# %%
#correlation matrix to quickly see if there are any features with missing values that correlate well with features without missing values.

listings.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row0_col0,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row1_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col2,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row3_col3,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row4_col4,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row5_col5,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row6_col6,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row6_col7,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row7_col6,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row7_col7,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row8_col8,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row9_col9,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row10_col10,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row11_col11,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row12_col12,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row13_col13,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row14_col14,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row15_col15,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row16_col16,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row17_col17,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row18_col18,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col19,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row20_col20,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row21_col21,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row21_col22,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row21_col24,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row22_col21,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row22_col22,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row22_col24,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col23,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row24_col21,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row24_col22,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row24_col24,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row25_col25,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row26_col26,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row27_col27,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row28_col28,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col29,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col30,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row31_col31,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row32_col32,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row33_col33,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row34_col34,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row35_col35,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col36,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col37,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row38_col38,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row39_col39,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row40_col40,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row41_col41,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row42_col42,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row43_col43,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row44_col44{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row0_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row0_col29,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col5,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col8,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col9,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row2_col37,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row3_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row4_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row5_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row5_col18,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row6_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row7_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row8_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row9_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row10_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row11_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row12_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row13_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row14_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row15_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row16_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row16_col44,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row17_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row17_col3,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row17_col30,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row17_col31,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row18_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col3,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col4,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col30,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col31,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row19_col39,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row20_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row20_col30,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row21_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row22_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col3,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col4,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col30,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col31,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row23_col39,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row24_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row25_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row26_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row27_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row28_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col0,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col2,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col12,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col13,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col14,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row29_col15,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col17,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col19,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col20,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col23,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row30_col28,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row31_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row32_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row32_col42,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row33_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row33_col43,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row34_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row35_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col6,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col7,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col40,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row36_col41,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col1,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col10,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col11,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col21,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row37_col22,#T_6ff1e8ea_67c1_11eb_8db4 ...
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row0_col2,#T_6ff1e8ea_67c1_11eb_8db4_1e00620e3d91row35_col32{
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }#T_6ff1e8ea_67c1_11eb_8db4_1e00

# %%
#looks like the complete 'accommodates' feature is strongly correlated with number of rooms, bathrooms and beds.

rooms = ['bathrooms_text','bedrooms','beds']
for column in listings[rooms]:
    print(str(column) +': ' +str(listings['accommodates'].corr(listings[column])))
# Out:
# bathrooms_text: 0.6971949883350813
# bedrooms: 0.8629902020445149
# beds: 0.8276720250216784

# %%
#since there is correation, I'll group by 'accommodates' before filling these features witht the average. This might 
#might give me a more accurate representation 
#First I'll double checking to make sure there aren't any zero values or anything really high 
#in 'accommodates' that looks like a mistake

print(listings['accommodates'].unique())
print(listings['accommodates'].hist())
# Out:
# [ 4  3  2  6  7 16 14  5 10  1  8 12 15  9 13 11  0]
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#looks okay so I'll go ahead and fill in the missing values
for column in listings[rooms]:
    listings[column] = listings[column].fillna(listings.groupby('accommodates')[column].transform('mean'))

# %%
#Making column of how many days airbnb has operated as of today's date
print(listings.first_review[:5])
listings["days_active"]=(pd.Timestamp.today() -listings.first_review).dt.days
listings.days_active[:5]
# Out:
# 0   2011-03-07
# 1   2010-04-16
# 2   2010-07-04
# 3   2011-02-16
# 4   2011-03-15
# Name: first_review, dtype: datetime64[ns]
# 0    3623.0
# 1    3948.0
# 2    3869.0
# 3    3642.0
# 4    3615.0
# Name: days_active, dtype: float64

# %%
#May want to limit data to airbnbs that have been operating longer because more people might stay in these each month
#but reviews doesn't look to be that correlated with how often they are booked
print(len(listings))
print(len(listings[listings['days_active']>365]))
print(len(listings[listings['days_active']>180]))
print(listings.days_active.corr(listings.reviews_per_month))
# Out:
# 6350
# 4999
# 5532
# 0.10780379367285746

# %%
listings.drop(columns = ['first_review','last_review'], inplace = True)

# %%
#I wasn't able to look at histograms by running them without separating them into integers and floats for some reason
l_ints = []
l_floats = []
for column, dtype in listings.dtypes.iteritems():
    if dtype == 'int64':
        l_ints.append(column)
    if dtype == 'float64':
        l_floats.append(column)

# %%
listings[l_ints].hist(bins = 10, figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'scrape_id'}>,
#         <AxesSubplot:title={'center':'host_id'}>,
#         <AxesSubplot:title={'center':'host_listings_count'}>],
#        [<AxesSubplot:title={'center':'host_total_listings_count'}>,
#         <AxesSubplot:title={'center':'accommodates'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>,
#         <AxesSubplot:title={'center':'maximum_nights'}>],
#        [<AxesSubplot:title={'center':'availability_30'}>,
#         <AxesSubplot:title={'center':'availability_60'}>,
#         <AxesSubplot:title={'center':'availability_90'}>,
#         <AxesSubplot:title={'center':'availability_365'}>],
#        [<AxesSubplot:title={'center':'number_of_reviews'}>,
#         <AxesSubplot:title={'center':'number_of_reviews_ltm'}>,
#         <AxesSubplot:title={'center':'number_of_reviews_l30d'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count'}>],
#        [<AxesSubplot:title={'center':'calculated_host_listings_count_entire_homes'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count_private_rooms'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count_shared_rooms'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
listings[l_floats].hist(bins=10,figsize=(50,50))
# Out:
# array([[<AxesSubplot:title={'center':'host_response_rate'}>,
#         <AxesSubplot:title={'center':'host_acceptance_rate'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'bathrooms_text'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'beds'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'minimum_minimum_nights'}>,
#         <AxesSubplot:title={'center':'maximum_minimum_nights'}>],
#        [<AxesSubplot:title={'center':'minimum_maximum_nights'}>,
#         <AxesSubplot:title={'center':'maximum_maximum_nights'}>,
#         <AxesSubplot:title={'center':'minimum_nights_avg_ntm'}>,
#         <AxesSubplot:title={'center':'maximum_nights_avg_ntm'}>,
#         <AxesSubplot:title={'center':'review_scores_rating'}>],
#        [<AxesSubplot:title={'center':'review_scores_accuracy'}>,
#         <AxesSubplot:title={'center':'review_scores_cleanliness'}>,
#         <AxesSubplot:title={'center':'review_scores_checkin'}>,
#         <AxesSubplot:title={'center':'review_scores_communication'}>,
#         <AxesSubplot:title={'center':'review_scores_location'}>],
#        [<AxesSubplot:title={'center':'review_scores_value'}>,
#         <AxesSubplot:title={'center':'reviews_per_month'}>,
#         <AxesSubplot:title={'center':'days_active'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#host listings count, looks weird so I'll check it out
print(listings[['name','host_name','host_id','license','host_listings_count']][listings['host_listings_count']>1500])
# Out:
#                                                    name  host_name    host_id  \
# 4055      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 5089      Club La Pension, New Orleans, 1 Bedroom Suite  Christian  194953121
# 5145      Club La Pension, New Orleans, 1 Bedroom Suite  Christian  194953121
# 5146          Ghouling Club La Pension, 1 Bedroom Suite  Christian  194953121
# 5148  The Marquee Resort, New Orleans,1 Bedroom Stan...  Christian  194953121
# 5149   The Marquee Resort, 1 Bedroom Deluxe Sleeps Four  Christian  194953121
# 5150        The Marquee Resort, Huge 1 Bedroom Standard  Christian  194953121
# 5151             The Marquee Resort, 2 Bedroom Standard  Christian  194953121
# 5153          The Marquee Resort, Huge 1 Bedroom Deluxe  Christian  194953121
# 5154        The Marquee Resort, Huge 1 Bedroom Standard  Christian  194953121
# 5155  The Marquee Resort, 1 Bedroom Standard Sleeps Two  Christian  194953121
# 5567       The Bayou's Club La Pension, 2 Bedroom Suite  Christian  194953121
# 5713        Rendezvous at Club La Pension™ -  2 Bedroom  Christian  194953121
# 5720  Classy Club Wyndham Avenue Plaza, 1 Bedroom De...  Christian  194953121
# 5721                  Elegant Club Wyndham Avenue Plaza  Christian  194953121
# 5722            Wyndham Avenue Plaza - 1 Bedroom Deluxe  Christian  194953121
# 5723  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5724  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5725    Classy Club Wyndham Avenue Plaza, Studio Deluxe  Christian  194953121
# 5726   Elegant Club Wyndham Avenue Plaza, Studio Deluxe  Christian  194953121
# 5727  Club Wyndham Avenue Plaza, New Orleans, Louisiana  Christian  194953121
# 5888  The Marquee Resort, Commodious 1 Bedroom Standard  Christian  194953121
# 5889    The Marquee Resort, 1 Bedroom Standard Sleeps 2  Christian  194953121
# 5890    The Marquee Resort, Spacious 1 Bedroom Standard  Christian  194953121
# 6257             French Quarter Prime Location Sleeps 4  Christian  194953121
# 6258      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 6259      Exhilarating Club La Pension, 1 Bedroom Suite  Christian  194953121
# 6284          The Marquee - Stunning 1 Bedroom Standard  Christian  194953121
#
#                                                 license  host_listings_count
# 4055  Exempt: This listing is a licensed hotel, mote...                 1916
# 5089  Exempt: This listing is a licensed hotel, mote...                 1916
# 5145  Exempt: This listing is a licensed hotel, mote...                 1916
# 5146  Exempt: This listing is a licensed hotel, mote...                 1916
# 5148  Exempt: This listing is a licensed hotel, mote...                 1916
# 5149  Exempt: This listing is a licensed hotel, mote...                 1916
# 5150  Exempt: This listing is a licensed hotel, mote...                 1916
# 5151  Exempt: This listing is a licensed hotel, mote...                 1916
# 5153  Exempt: This listing is a licensed hotel, mote...                 1916
# 5154  Exempt: This listing is a licensed hotel, mote...                 1916
# 5155  Exempt: This listing is a licensed hotel, mote...                 1916
# 5567  Exempt: This listing is a licensed hotel, mote...                 1916
# 5713  Exempt: This listing is a licensed hotel, mote...                 1916
# 5720  Exempt: This listing is a licensed hotel, mote...                 1916
# 5721  Exempt: This listing is a licensed hotel, mote...                 1916
# 5722  Exempt: This listing is a licensed hotel, mote...                 1916
# 5723  Exempt: This listing is a licensed hotel, mote...                 1916
# 5724  Exempt: This listing is a licensed hotel, mote...                 1916
# 5725  Exempt: This listing is a licensed hotel, mote...                 1916
# 5726  Exempt: This listing is a licensed hotel, mote...                 1916
# 5727  Exempt: This listing is a licensed hotel, mote...                 1916
# 5888  Exempt: This listing is a licensed hotel, mote...                 1916
# 5889  Exempt: This listing is a licensed hotel, mote...                 1916
# 5890  Exempt: This listing is a licensed hotel, mote...                 1916
# 6257  Exempt: This listing is a licensed hotel, mote...                 1916
# 6258  Exempt: This listing is a licensed hotel, mote...                 1916
# 6259  Exempt: This listing is a licensed hotel, mote...                 1916
# 6284  Exempt: This listing is a licensed hotel, mote...                 1916

# %%
print(listings[listings['host_id']==194953121].shape)
print(listings[listings['host_name']=='Christian'].shape)
print(listings[listings['license']=='Exempt: This listing is a licensed hotel, motel, or bed and breakfast'].shape)
#can't see how this host's host_listings_count can be greater than 28. 1125 at the most, but it showed up filtered by host listing count greater than 1500.
# Out:
# (28, 65)
# (35, 65)
# (1112, 65)

# %%
print(listings[['name','host_name','host_id','license','host_listings_count','calculated_host_listings_count']][listings['calculated_host_listings_count']>100])
print(listings[listings['host_name']=='Hosteeva'].shape)
print(listings[listings['host_id']==24831061].shape)
# calculated host listings count looks to have been determined by host_id and more accurate, so I'll keep it and remove other columns related to number of host listings
# Out:
#                                                  name host_name   host_id  \
# 1115       Spacious 3BR Condo close to French Quarter  Hosteeva  24831061
# 1117         Luxury 4BR Penthouse Near French Quarter  Hosteeva  24831061
# 1119                     Luxury 4BR condo in Downtown  Hosteeva  24831061
# 1240         Lovely 2BR next to City Park by Hosteeva  Hosteeva  24831061
# 1249       Stunning 1BR next to City Park by Hosteeva  Hosteeva  24831061
# ...                                               ...       ...       ...
# 4938                        Luxury Living in Mid City  Hosteeva  24831061
# 5115      Hosteeva | Double on Martin Luther King Jr.  Hosteeva  24831061
# 5122  Hosteeva | 2BR Double Steps to St. Charles Ave.  Hosteeva  24831061
# 5529                     Lovely 3BR next to City Park  Hosteeva  24831061
# 5530                         1812 #3 Luxury 3BR Condo  Hosteeva  24831061
#
#                          license  host_listings_count  \
# 1115  20STR-21055, 20-OSTR-00670                  624
# 1117   20STR-21055, 20-OSTR-0670                  624
# 1119   20STR-21055, 20-OSTR-0670                  624
# 1240   18STR-20431, 20-OSTR-0670                  624
# 1249   18STR-10509, 20-OSTR-0670                  624
# ...                          ...                  ...
# 4938   19STR-09096, 20-OSTR-0670                  624
# 5115   19STR-21847, 20-OSTR-0670                  624
# 5122   19STR-21843, 20-OSTR-0670                  624
# 5529   19STR-12359, 20-OSTR-0670                  624
# 5530   18STR-13759, 20-OSTR-0670                  624
#
#       calculated_host_listings_count
# 1115                             142
# 1117                             142
# 1119                             142
# 1240                             142
# 1249                             142
# ...                              ...
# 4938                             142
# 5115                             142
# 5122                             142
# 5529                             142
# 5530                             142
#
# [142 rows x 6 columns]
# (186, 65)
# (142, 65)

# %%
listings.drop(columns = ['host_listings_count','host_total_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms'],inplace=True)

# %%
#columns related to minimum and maximum nights look strange or repetitive in histograms
#New Orleans defines the length of short-term rentals as rentals as less than 30 days
print(listings[listings['minimum_nights']>29].shape)
print(listings[listings['license']=='Long-term host, exempt from registration'].shape)
listings = listings[listings['license']!='Long-term host, exempt from registration']
# Out:
# (1296, 60)
# (4, 60)

# %%
#there are enough listings with a high minimum nights value to try to figure out a good replacement value rather 
#than deleting them
min_nights = list(listings['minimum_nights'][listings['minimum_nights']>29])
min_nights.sort(reverse = True)
print(min_nights)
# Out:
# [360, 360, 180, 180, 180, 120, 100, 90, 90, 90, 90, 90, 90, 90, 90, 89, 60, 60, 60, 60, 60, 60, 60, 60, 45, 32, 32, 32, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,  ...

# %%
#most listings above 29 minimumn nights are 30 nights. They could be listed this way to circumvent some of NOLA's short term rental laws so 
#I'll keep anything 30 nights or fewer.
listings=listings[listings['minimum_nights']<31]

# %%
listings.drop(columns = ['minimum_minimum_nights','maximum_minimum_nights','minimum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm'],inplace = True)

# %%
#creates a column of estimated earnings per month assuming the guests only stayed the minimum nights
listings['lowest_estimate/month']=listings['price']*listings['reviews_per_month']*listings['minimum_nights']
print(listings["lowest_estimate/month"].head())
print(listings['lowest_estimate/month'].mean())
print(listings['lowest_estimate/month'].max())
# Out:
# 0     324.00
# 1     221.40
# 2     550.02
# 3     756.60
# 4    1184.04
# Name: lowest_estimate/month, dtype: float64
# 1178.4588610382598
# 49276.50000000001

# %%
conditions = [(listings['minimum_nights']>5),(listings['minimum_nights']<=5)]
values = [(listings['lowest_estimate/month']),(listings['price']*listings['reviews_per_month']*5)]
listings['middle_estimate/month']=np.select(conditions, values)
print(listings['middle_estimate/month'].head())
print(listings['middle_estimate/month'].mean())
print(listings['middle_estimate/month'].max())
# Out:
# 0     810.0
# 1    1107.0
# 2     916.7
# 3    1261.0
# 4    1973.4
# Name: middle_estimate/month, dtype: float64
# 1817.8910539428734
# 49276.50000000001

# %%
#these seem really high
#I need to check to see if there are rows where number of reviews per month multplied by minimum_nights
#outnumber the number of days in a month 
#I'm going to remove these rows
print(listings[['minimum_nights','reviews_per_month']][(listings['minimum_nights']*listings['reviews_per_month'])>30])
listings = listings[(listings['minimum_nights']*listings['reviews_per_month'])<30]
print(listings['middle_estimate/month'].mean())
print(listings['middle_estimate/month'].max())
print(listings['lowest_estimate/month'].mean())
print(listings['lowest_estimate/month'].max())
# Out:
#       minimum_nights  reviews_per_month
# 12                30               1.29
# 34                30               1.61
# 36                30               1.21
# 40                30               1.67
# 46                30               2.32
# ...              ...                ...
# 4884              30               2.47
# 4910              30               1.42
# 4914              30               1.85
# 5008              30               1.64
# 5980              30               2.12
#
# [400 rows x 2 columns]
# 1390.6043111003485
# 18873.0
# 701.003571483921
# 18873.0

# %%
#host acceptance rate showed some zero values in histogram
print(len(listings[listings['host_acceptance_rate']==0]))

#I'll go ahead and delete these since there are so few
listings = listings[listings['host_acceptance_rate']>0]
# Out:
# 40

# %%
#deleting listings that have no reviews. I want the model to work on airbnbs that have been 'tested'
print(len(listings[listings['number_of_reviews']==0]))
listings = listings[listings['number_of_reviews'] > 0]
# Out:
# 0

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4776 entries, 0 to 6382
# Data columns (total 56 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4776 non-null   int64
#  1   scrape_id                       4776 non-null   int64
#  2   last_scraped                    4776 non-null   object
#  3   name                            4776 non-null   object
#  4   description                     4772 non-null   object
#  5   neighborhood_overview           3748 non-null   object
#  6   host_id                         4776 non-null   int64
#  7   host_name                       4776 non-null   object
#  8   host_since                      4776 non-null   object
#  9   host_location                   4767 non-null   object
#  10  host_about                      3297 non-null   object
#  11  host_response_time              3926 non-null   category
#  12  host_response_rate              3926 non-null   float64
#  13  host_acceptance_rate            4776 non-null   float64
#  14  host_is_superhost               4776 non-null   bool
#  15  host_neighbourhood              4369 non-null   object
#  16  host_verifications              4776 non-null   object
#  17  host_has_profile_pic            4776 non-null   bool
#  18  host_identity_verified          4776 non-null   bool
#  19  neighbourhood                   3748 non-null   object
#  20  neighbourhood_cleansed          4776 non-null   category
#  21  latitude                        4776 non-null   float64
#  22  longitude                       4776 non-null   float64
#  23  property_type                   4776 non-null   category
#  24  room_type                       4776 non-null   category
#  25  accommodates                    4776 non-null   int64
#  26  bathrooms_text                  4776 non-null   float64
#  27  bedrooms                        4776 non-null   float64
#  28  beds                            4776 non-null   float64
#  29  amenities                       4776 non-null   object
#  30  price                           4776 non-null   float64
#  31  minimum_nights                  4776 non-null   int64
#  32  maximum_nights                  4776 non-null   int64
#  33  has_availability                4776 non-null   object
#  34  availability_30                 4776 non-null   int64
#  35  availability_60                 4776 non-null   int64
#  36  availability_90                 4776 non-null   int64
#  37  availability_365                4776 non-null   int64
#  38  calendar_last_scraped           4776 non-null   object
#  39  number_of_reviews               4776 non-null   int64
#  40  number_of_reviews_ltm           4776 non-null   int64
#  41  number_of_reviews_l30d          4776 non-null   int64
#  42  review_scores_rating            4770 non-null   float64
#  43  review_scores_accuracy          4760 non-null   float64
#  44  review_scores_cleanliness       4760 non-null   float64
#  45  review_scores_checkin           4760 non-null   float64
#  46  review_scores_communication     4760 non-null   float64
#  47  review_scores_location          4760 non-null   float64
#  48  review_scores_value             4760 non-null   float64
#  49  license                         4600 non-null   object
#  50  instant_bookable                4776 non-null   bool
#  51  calculated_host_listings_count  4776 non-null   int64
#  52  reviews_per_month               4776 non-null   float64
#  53  days_active                     4776 non-null   float64
#  54  lowest_estimate/month           4776 non-null   float64
#  55  middle_estimate/month           4776 non-null   float64
# dtypes: bool(4), category(4), float64(19), int64(14), object(15)
# memory usage: 1.8+ MB
# None

# %%
listings.drop (columns =['neighbourhood','last_scraped','host_neighbourhood','host_id','host_since','has_availability','calendar_last_scraped','number_of_reviews_ltm','license','host_verifications'],inplace=True)

# %%
#I could probably fill in some more of the missing values, but I'm happy with this amount of data for now. 
print(listings.shape)

listings = listings.dropna()
print(listings.shape)
# Out:
# (4776, 46)
# (2241, 46)

# %%
print(listings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2241 entries, 0 to 6372
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2241 non-null   int64
#  1   scrape_id                       2241 non-null   int64
#  2   name                            2241 non-null   object
#  3   description                     2241 non-null   object
#  4   neighborhood_overview           2241 non-null   object
#  5   host_name                       2241 non-null   object
#  6   host_location                   2241 non-null   object
#  7   host_about                      2241 non-null   object
#  8   host_response_time              2241 non-null   category
#  9   host_response_rate              2241 non-null   float64
#  10  host_acceptance_rate            2241 non-null   float64
#  11  host_is_superhost               2241 non-null   bool
#  12  host_has_profile_pic            2241 non-null   bool
#  13  host_identity_verified          2241 non-null   bool
#  14  neighbourhood_cleansed          2241 non-null   category
#  15  latitude                        2241 non-null   float64
#  16  longitude                       2241 non-null   float64
#  17  property_type                   2241 non-null   category
#  18  room_type                       2241 non-null   category
#  19  accommodates                    2241 non-null   int64
#  20  bathrooms_text                  2241 non-null   float64
#  21  bedrooms                        2241 non-null   float64
#  22  beds                            2241 non-null   float64
#  23  amenities                       2241 non-null   object
#  24  price                           2241 non-null   float64
#  25  minimum_nights                  2241 non-null   int64
#  26  maximum_nights                  2241 non-null   int64
#  27  availability_30                 2241 non-null   int64
#  28  availability_60                 2241 non-null   int64
#  29  availability_90                 2241 non-null   int64
#  30  availability_365                2241 non-null   int64
#  31  number_of_reviews               2241 non-null   int64
#  32  number_of_reviews_l30d          2241 non-null   int64
#  33  review_scores_rating            2241 non-null   float64
#  34  review_scores_accuracy          2241 non-null   float64
#  35  review_scores_cleanliness       2241 non-null   float64
#  36  review_scores_checkin           2241 non-null   float64
#  37  review_scores_communication     2241 non-null   float64
#  38  review_scores_location          2241 non-null   float64
#  39  review_scores_value             2241 non-null   float64
#  40  instant_bookable                2241 non-null   bool
#  41  calculated_host_listings_count  2241 non-null   int64
#  42  reviews_per_month               2241 non-null   float64
#  43  days_active                     2241 non-null   float64
#  44  lowest_estimate/month           2241 non-null   float64
#  45  middle_estimate/month           2241 non-null   float64
# dtypes: bool(4), category(4), float64(19), int64(12), object(7)
# memory usage: 706.6+ KB
# None

# %%
print(market_value.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   the_geom                                 496 non-null    object
#  1   OBJECTID                                 496 non-null    int64
#  2   geoid                                    496 non-null    int64
#  3   Median Sales Price                       496 non-null    float64
#  4   Coefficient for Variance of Sales Price  496 non-null    float64
#  5   Cluster                                  496 non-null    object
#  6   PercentVacantLandSales                   496 non-null    float64
#  7   PercentSubsidizedRental                  496 non-null    float64
#  8   PercentInspectionViolations              496 non-null    float64
#  9   PercentResidentialAddressesVacant        496 non-null    float64
#  10  PercentVacantLots                        496 non-null    float64
#  11  PercentForeclosure                       496 non-null    float64
#  12  PercentShortTermRentals                  496 non-null    float64
#  13  PercentOwnerOccupied                     496 non-null    float64
#  14  PercentNewConstruction                   496 non-null    float64
#  15  CFCL_ALL16                               496 non-null    int64
#  16  PabnbUhh                                 496 non-null    float64
#  17  Cluster Letter                           446 non-null    object
#  18  PVIOL1617                                496 non-null    float64
#  19  MedianSalesPrice                         0 non-null      float64
#  20  PRENOCONST                               496 non-null    float64
#  21  PctResVac                                496 non-null    float64
#  22  PVACSALES1                               496 non-null    float64
#  23  PHCVPBV_Al                               496 non-null    float64
#  24  PHHOO                                    496 non-null    float64
#  25  PVACDRM_xV                               496 non-null    float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 100.9+ KB
# None

# %%
#I'll only use columns I want for summary statistics and geospatial data.
market_value = market_value[['the_geom','OBJECTID','geoid', 'Median Sales Price','PercentShortTermRentals']]

# %%
market_value.hist(bins=10, figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'OBJECTID'}>,
#         <AxesSubplot:title={'center':'geoid'}>],
#        [<AxesSubplot:title={'center':'Median Sales Price'}>,
#         <AxesSubplot:title={'center':'PercentShortTermRentals'}>]],
#       dtype=object)

# %%
#converting listings to geodataframe in order to merge with market value data via gps coordinates
gdf_listings = gpd.GeoDataFrame(listings,   geometry=gpd.points_from_xy(listings.longitude, listings.latitude))

# %%
#changing the_geom column of market_value to correct type for geodataframe geometry column
market_value['geometry'] = market_value['the_geom'].apply(wkt.loads)

# %%
#converting market_value to geodataframe 
m_value_gpd = gpd.GeoDataFrame(market_value, geometry = market_value['geometry'])

# %%
#joining based on gps coordinates
sjoined_listings = gpd.sjoin(m_value_gpd, gdf_listings, op= 'contains' )

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   the_geom  867 non-null    object
#  1   OBJECTID  883 non-null    int64
#  2   Name      883 non-null    object
#  3   Segment   883 non-null    object
#  4   Type      883 non-null    object
#  5   Address   878 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 41.5+ KB

# %%
print(restaurants[restaurants['Address'].duplicated()].shape)
print(restaurants[restaurants['Address']=='3901 BANKS  ST'])

#there are some addresses listing multiple restaurants because of a business having retail and dining licenses
#some addresses contain names of previous restaurants and current restaurants
#some addresses are large enough to hold several retaurants
#without spending a lot of time researching this, I think its safe to remove duplicate addresses.  Even it is a food
#court or something, it will be counted as one restaurant. 
restaurants.drop_duplicates(subset = ['Address'], inplace = True)
# Out:
# (48, 6)
#                                      the_geom  OBJECTID  \
# 687  POINT (-90.100966696726 29.970772242784)        37
# 742  POINT (-90.100966696726 29.970772242784)       450
#
#                       Name        Segment           Type         Address
# 687  MONA'S PITA BREAD INC  Culinary Arts  Food Products  3901 BANKS  ST
# 742            MONA'S CAFE  Culinary Arts     Restaurant  3901 BANKS  ST

# %%
#dropped ojectid from restaurants before merging since it is a duplicate column name
restaurants.drop(columns = 'OBJECTID', inplace = True)
restaurants.dropna(inplace = True)
restaurants['the_geom']=restaurants['the_geom'].apply(wkt.loads)
restaurants_gpd = gpd.GeoDataFrame(restaurants, geometry = 'the_geom')

# %%
#joined restaurants to neighborhoods grouped by the number of restaurants in the neighborhood

restaurants_neighborhoods=gpd.sjoin(m_value_gpd, restaurants_gpd, op='contains')

#create dataframe of restaurants counts grouped by 'geoid' which is the district they're in
restaurants_neighborhoods = restaurants_neighborhoods.groupby('geoid').Name.agg('count').reset_index()

# %%
#rename

restaurants_neighborhoods.rename(columns = {'Name':'Restaurant_Count'}, inplace = True)

# %%
#this is a left join on geoid so that restaurants info will show number of restaurants per district
sjoined_listings = pd.merge(sjoined_listings,restaurants_neighborhoods,how = 'left', left_on = 'geoid', right_on = 'geoid')

# %%
sjoined_listings.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 2241 entries, 0 to 2240
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   the_geom                        2241 non-null   object
#  1   OBJECTID                        2241 non-null   int64
#  2   geoid                           2241 non-null   int64
#  3   Median Sales Price              2241 non-null   float64
#  4   PercentShortTermRentals         2241 non-null   float64
#  5   geometry                        2241 non-null   geometry
#  6   index_right                     2241 non-null   int64
#  7   id                              2241 non-null   int64
#  8   scrape_id                       2241 non-null   int64
#  9   name                            2241 non-null   object
#  10  description                     2241 non-null   object
#  11  neighborhood_overview           2241 non-null   object
#  12  host_name                       2241 non-null   object
#  13  host_location                   2241 non-null   object
#  14  host_about                      2241 non-null   object
#  15  host_response_time              2241 non-null   category
#  16  host_response_rate              2241 non-null   float64
#  17  host_acceptance_rate            2241 non-null   float64
#  18  host_is_superhost               2241 non-null   bool
#  19  host_has_profile_pic            2241 non-null   bool
#  20  host_identity_verified          2241 non-null   bool
#  21  neighbourhood_cleansed          2241 non-null   category
#  22  latitude                        2241 non-null   float64
#  23  longitude                       2241 non-null   float64
#  24  property_type                   2241 non-null   category
#  25  room_type                       2241 non-null   category
#  26  accommodates                    2241 non-null   int64
#  27  bathrooms_text                  2241 non-null   float64
#  28  bedrooms                        2241 non-null   float64
#  29  beds                            2241 non-null   float64
#  30  amenities                       2241 non-null   object
#  31  price                           2241 non-null   float64
#  32  minimum_nights                  2241 non-null   int64
#  33  maximum_nights                  2241 non-null   int64
#  34  availability_30                 2241 non-null   int64
#  35  availability_60                 2241 non-null   int64
#  36  availability_90                 2241 non-null   int64
#  37  availability_365                2241 non-null   int64
#  38  number_of_reviews               2241 non-null   int64
#  39  number_of_reviews_l30d          2241 non-null   int64
#  40  review_scores_rating            2241 non-null   float64
#  41  review_scores_accuracy          2241 non-null   float64
#  42  review_scores_cleanliness       2241 non-null   float64
#  43  review_scores_checkin           2241 non-null   float64
#  44  review_scores_communication     2241 non-null   float64
#  45  review_scores_location          2241 non-null   float64
#  46  review_scores_value             2241 non-null   float64
#  47  instant_bookable                2241 non-null   bool
#  48  calculated_host_listings_count  2241 non-null   int64
#  49  reviews_per_month               2241 non-null   float64
#  50  days_active                     2241 non-null   float64
#  51  lowest_estimate/month           2241 non-null   float64
#  52  middle_estimate/month           2241 non-null   float64
#  53  Restaurant_Count                1557 non-null   float64
# dtypes: bool(4), category(4), float64(22), geometry(1), int64(15), object(8)
# memory usage: 846.7+ KB

# %%
#this shows that there are multiple geoids in each neighborhood
print(len(sjoined_listings.neighbourhood_cleansed.unique()))

print(len(sjoined_listings.geoid.unique()))
# Out:
# 61
# 324

# %%
#this shows that there are geoids in neighborhoods with no restaurants.
neighborhoods = sjoined_listings.groupby(['neighbourhood_cleansed','geoid']).Restaurant_Count.agg('max')

# %%
#this left joins neighborhoods to main dataframe so that each entry
#has a column that shows how many restaurants are in its neighborhood
neighborhoods = neighborhoods.reset_index()
neighborhoods = neighborhoods.groupby('neighbourhood_cleansed').Restaurant_Count.agg('sum')
neighborhoods = neighborhoods.to_frame().reset_index()
neighborhoods.rename(columns = {'Restaurant_Count':'neighborhood_restaurants'},inplace=True)
geolistings = pd.merge(sjoined_listings,neighborhoods,how = 'left', left_on = 'neighbourhood_cleansed', right_on = 'neighbourhood_cleansed')

# %%
#this is just some code to show me which neighborhoods the data shows no restaurants for
#These neighborhoods are industrial, highly suburban or very impovershed so it looks reasonable to me
geolistings.update(geolistings[['Restaurant_Count','neighborhood_restaurants']].fillna(0))
print(geolistings.shape)
print(len(geolistings[geolistings['neighborhood_restaurants']>0]))
group = geolistings[['neighbourhood_cleansed','neighborhood_restaurants']].groupby('neighbourhood_cleansed').neighborhood_restaurants.agg('max')
group = group.reset_index()

print(group.info())
print(group[group['neighborhood_restaurants'].isna()])
print(group[group['neighborhood_restaurants']==0])
# Out:
# (2241, 55)
# 2189
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   neighbourhood_cleansed    71 non-null     category
#  1   neighborhood_restaurants  61 non-null     float64
# dtypes: category(1), float64(1)
# memory usage: 3.8 KB
# None
#       neighbourhood_cleansed  neighborhood_restaurants
# 13                     Dixon                       NaN
# 18               Fischer Dev                       NaN
# 31       Lake Terrace & Oaks                       NaN
# 48             Pines Village                       NaN
# 49              Plum Orchard                       NaN
# 52            Read Blvd West                       NaN
# 63           U.S. Naval Base                       NaN
# 65  Viavant - Venetian Isles                       NaN
# 66           Village De Lest                       NaN
# 68          West Lake Forest                       NaN
#        neighbourhood_cleansed  neighborhood_restaurants
# 2                B. W. Cooper                       0.0
# 4                     Behrman                       0.0
# 19               Florida Area                       0.0
# 24             Gentilly Woods                       0.0
# 26                 Hollygrove                       0.0
# 30             Lake Catherine                       0.0
# 33                   Lakeview                       0.0
# 46  New Aurora - English Turn                       0.0
# 47                 Old Aurora                       0.0
# 50         Pontchartrain Park                       0.0
# 55           St. Bernard Area                       0.0
# 70                    Whitney                       0.0

# %%
print(len(geolistings.neighbourhood_cleansed.unique()))
print(group[group['neighbourhood_cleansed']=='Dixon'])
print(geolistings[geolistings['neighbourhood_cleansed']=="Dixon"].shape)
# Out:
# 61
#    neighbourhood_cleansed  neighborhood_restaurants
# 13                  Dixon                       NaN
# (0, 55)

# %%
geolistings.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 2241 entries, 0 to 2240
# Data columns (total 55 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   the_geom                        2241 non-null   object
#  1   OBJECTID                        2241 non-null   int64
#  2   geoid                           2241 non-null   int64
#  3   Median Sales Price              2241 non-null   float64
#  4   PercentShortTermRentals         2241 non-null   float64
#  5   geometry                        2241 non-null   geometry
#  6   index_right                     2241 non-null   int64
#  7   id                              2241 non-null   int64
#  8   scrape_id                       2241 non-null   int64
#  9   name                            2241 non-null   object
#  10  description                     2241 non-null   object
#  11  neighborhood_overview           2241 non-null   object
#  12  host_name                       2241 non-null   object
#  13  host_location                   2241 non-null   object
#  14  host_about                      2241 non-null   object
#  15  host_response_time              2241 non-null   category
#  16  host_response_rate              2241 non-null   float64
#  17  host_acceptance_rate            2241 non-null   float64
#  18  host_is_superhost               2241 non-null   bool
#  19  host_has_profile_pic            2241 non-null   bool
#  20  host_identity_verified          2241 non-null   bool
#  21  neighbourhood_cleansed          2241 non-null   category
#  22  latitude                        2241 non-null   float64
#  23  longitude                       2241 non-null   float64
#  24  property_type                   2241 non-null   category
#  25  room_type                       2241 non-null   category
#  26  accommodates                    2241 non-null   int64
#  27  bathrooms_text                  2241 non-null   float64
#  28  bedrooms                        2241 non-null   float64
#  29  beds                            2241 non-null   float64
#  30  amenities                       2241 non-null   object
#  31  price                           2241 non-null   float64
#  32  minimum_nights                  2241 non-null   int64
#  33  maximum_nights                  2241 non-null   int64
#  34  availability_30                 2241 non-null   int64
#  35  availability_60                 2241 non-null   int64
#  36  availability_90                 2241 non-null   int64
#  37  availability_365                2241 non-null   int64
#  38  number_of_reviews               2241 non-null   int64
#  39  number_of_reviews_l30d          2241 non-null   int64
#  40  review_scores_rating            2241 non-null   float64
#  41  review_scores_accuracy          2241 non-null   float64
#  42  review_scores_cleanliness       2241 non-null   float64
#  43  review_scores_checkin           2241 non-null   float64
#  44  review_scores_communication     2241 non-null   float64
#  45  review_scores_location          2241 non-null   float64
#  46  review_scores_value             2241 non-null   float64
#  47  instant_bookable                2241 non-null   bool
#  48  calculated_host_listings_count  2241 non-null   int64
#  49  reviews_per_month               2241 non-null   float64
#  50  days_active                     2241 non-null   float64
#  51  lowest_estimate/month           2241 non-null   float64
#  52  middle_estimate/month           2241 non-null   float64
#  53  Restaurant_Count                2241 non-null   float64
#  54  neighborhood_restaurants        2241 non-null   float64
# dtypes: bool(4), category(4), float64(23), geometry(1), int64(15), object(8)
# memory usage: 864.2+ KB

# %%
ints = []
floats = []
for column, dtype in geolistings.dtypes.iteritems():
    if dtype == 'int64':
        ints.append(column)
    if dtype == 'float64':
        floats.append(column)

# %%
geolistings[ints].hist(bins = 10, figsize= (75,75))
#the code below saves the charts to a pdf for easier viewing
pyplot.savefig('../reports/figures/amenities_histograms.pdf')

# %%
geolistings[floats].hist(bins = 10, figsize= (50,50))
# Out:
# array([[<AxesSubplot:title={'center':'Median Sales Price'}>,
#         <AxesSubplot:title={'center':'PercentShortTermRentals'}>,
#         <AxesSubplot:title={'center':'host_response_rate'}>,
#         <AxesSubplot:title={'center':'host_acceptance_rate'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'bathrooms_text'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'beds'}>,
#         <AxesSubplot:title={'center':'price'}>],
#        [<AxesSubplot:title={'center':'review_scores_rating'}>,
#         <AxesSubplot:title={'center':'review_scores_accuracy'}>,
#         <AxesSubplot:title={'center':'review_scores_cleanliness'}>,
#         <AxesSubplot:title={'center':'review_scores_checkin'}>,
#         <AxesSubplot:title={'center':'review_scores_communication'}>],
#        [<AxesSubplot:title={'center':'review_scores_location'}>,
#         <AxesSubplot:title={'center':'review_scores_value'}>,
#         <AxesSubplot:title={'center':'reviews_per_month'}>,
#         <AxesSubplot:title={'center':'days_active'}>,
#         <AxesSubplot:title={'center':'lowest_estimate/month'}>],
#        [<AxesSubplot:title={'center':'middle_estimate/month'}>,
#         <AxesSubplot:title={'center':'Restaurant_Count'}>,
#         <AxesSubplot:title={'center':'neighborhood_restaurants'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#this deletes any columns where each instance has the same value. These won't be useful 
print(geolistings.shape)
for col in geolistings.columns:
    if len(geolistings[col].unique()) == 1:
        geolistings.drop(col,inplace=True,axis=1)
print(geolistings.shape)
# Out:
# (2241, 55)
# (2241, 54)

# %% [markdown]
# I think the data is clean enough for EDA.  There will definitely be features removed after looking at it.
# I'm not sure if the target feature will be price per night.
# I'd rather make a model that can estimate how much an owner can make per month depending on controllable factors.

# %%
geolistings.to_csv(r'../data/cleaned_for_eda/airbnb.csv', index = False)
